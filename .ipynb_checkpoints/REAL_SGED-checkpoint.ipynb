# %% [markdown]
# # Remarks
#
# * Data normalization
#     * Mobilenet expects data from -1 to 1
#         * Normalize Input Data or Include in Model
#         * TFLite Conversion must fit according to decision
#     * Ground Truth Data: for better inspection Data multiplied by 80. Undo the change in the Data Input Pipeline
# * Overview in Tutorials:
#     * tf.function
#     * Repeat addapted Version of using Build in methods for training, ...
#     * Save models using keras
#         * CaseNet first real model: check implementation of Frey if a Layer needs to be written
#         * other Example: depth seperable dilated convolution,

# %% [markdown]
# # Libraries

# %%
#!for a in /sys/bus/pci/devices/*; do echo 0 | sudo tee -a $a/numa_node; done

import tensorflow as tf
import numpy as np
import os
import time
from datetime import datetime
#import sys
import matplotlib.pyplot as plt
import argparse

import DataProcessing.data_processing as data_processing
import Nets.backbones as backbones
import Nets.features as features
import Nets.losses as losses
import Nets.metrics as metrics
import Nets.visualize as visualize
import Nets.tools as tools


os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'

#np.set_printoptions(threshold=sys.maxsize)

# %% [markdown]
# # Parser

# %%
parser = argparse.ArgumentParser()

parser.add_argument('--model', type=str, required=False, default=None)
parser.add_argument('--model_loaded', type=str, required=False, default=None)
parser.add_argument('--data', type=str, required=False, default=None)
parser.add_argument('--data_base_model', type=str, required=False, default=None)

parser.add_argument('--bs', type=int, required=False, default=None)
parser.add_argument('--idx', type=int, required=False, default=None)
parser.add_argument('--epoch', type=int, required=False, default=None)

parser.add_argument('--train_model', action='store_true', default=False)
parser.add_argument('--cache', action='store_true', default=False)
parser.add_argument('--save', action='store_true', default=False)
parser.add_argument('--sigmoid', action='store_true', default=False)
parser.add_argument('--focal', action='store_true', default=False)

parser.add_argument('--beta_upper', type=float, required=False, default=None)
parser.add_argument('--gamma', type=float, required=False, default=None)
parser.add_argument('--alpha', type=float, required=False, default=None)

file_name = None
try:
    file_name = __file__
except:
    print("Jupyter Notebook")
       
if file_name is None:
    args = parser.parse_args("")
    args.train_model = False
    args.cache = True
    args.save = True
    args.sigmoid = False
    args.focal = True
else:    
    args = parser.parse_args()
# Out:
# Jupyter Notebook

# %% [markdown]
# # Options

# %%
# Generall Parameters
#MODEL= 'CASENET_FOCAL_LOSS_0.8_g2_a2_REAL' if args.model is None else args.model
MODEL= 'SGED_FOCAL_LOSS_0.5_g2_a2_REAL' if args.model is None else args.model
MODEL_LOADED = 'SGED_FOCAL_LOSS_0.5_g2_a2' if args.model_loaded is None else args.model_loaded
DATA = 'RealRed' if args.data is None else args.data
DATA_BASE_MODEL_LOADED = 'SceneNetFloorTiledTextureRandom' if args.data_base_model is None else args.data_base_model
# DATA_BASE_MODEL_LOADED = 'RealRed' if args.data_base_model is None else args.data_base_model

TRAIN_DS = 'Train'
TEST_DS = 'Test'
TEST_HARD_DS = 'Test Hard'
TEST_IMG_DS = 'Test IMG'
HALF = True

# Dataset Loading Parameters
IMG_SIZE_HEIGHT = 1280
IMG_SIZE_WIDTH = 720
NUM_CLASSES = 3
MAX_IMG_TRAIN = 80
MAX_IMG_TEST = 25
SEED = None
BATCH_SIZE = 4 if args.bs is None else args.bs
CACHE = args.cache


# Model Parameters
TRAINABLE_IDX = 3
EPOCHS = 100 if args.epoch is None else args.epoch
SAVE = args.save
TRAIN_MODEL = args.train_model

#Model Callback
MODEL_SAVE_EPOCH_FREQ = 5
DEL_OLD_CHECKPOINTS = False
TENSORBOARD = False
DEL_OLD_TENSORBOARD = True

# LOSS
weighted_multi_label_sigmoid_edge_loss = args.sigmoid
focal_loss = args.focal

beta_upper = 0.5 if args.beta_upper is None else args.beta_upper
beta_lower = 1.0 - beta_upper
gamma=2.0 if args.gamma is None else args.gamma 
alpha=2.0 if args.alpha is None else args.alpha
class_weighted = True
weighted_beta=True

THRESHOLD_EDGE_WIDTH_REAL = 1


# Data Augmentation:
#aug_param = {"contrast_factor": 0.7, "brightness": 0.05, "hue": 0.02, "saturation": 0.7, "gaussian_value": 0.00,
#            "value": 0.05, "strength_spot": 0.3, "blur": False, "sigma": 1.0}
aug_param = {"contrast_factor": 0.9, "brightness": 0.05, "hue": 0.02, "saturation": 0.9, "gaussian_value": 0.00,
            "value": 0.05, "strength_spot": 0.2, "blur": False, "sigma": 1.0}


#TESTING
test = False
if test:
    EPOCHS = 10
    MAX_IMG_TRAIN = 100
    MAX_IMG_TEST = 10

# %% [markdown]
# # Load Dataset, Preprocess Images and Dataset

# %%
tf.random.set_seed(SEED)

paths, files = data_processing.path_definitions(HALF, MODEL, DATA, TRAIN_DS, TEST_DS, TEST_HARD_DS, TEST_IMG_DS, 
                                                MODEL_LOADED, DATA_BASE_MODEL_LOADED, make_dirs=True)

data_processing.clean_model_directories(paths, DEL_OLD_CHECKPOINTS, DEL_OLD_TENSORBOARD)

rng = tf.random.Generator.from_seed(123, alg='philox')
train_ds, img_count_train = data_processing.load_dataset(paths,"TRAIN", IMG_SIZE_HEIGHT, IMG_SIZE_WIDTH, HALF, MAX_IMG_TRAIN)
train_ds = data_processing.dataset_processing(train_ds, cache=CACHE, shuffle=False, batch_size=BATCH_SIZE, 
                                              prefetch=True, img_count=img_count_train, augment=True, rng=rng, 
                                              aug_param=aug_param)

#train_ds_2, img_count_train = data_processing.load_dataset(paths,"TRAIN", IMG_SIZE_HEIGHT, IMG_SIZE_WIDTH, HALF, MAX_IMG_TRAIN)
#train_ds_2 = data_processing.dataset_processing(train_ds_2, cache=CACHE, shuffle=True, batch_size=BATCH_SIZE, 
#                                              prefetch=True, img_count=img_count_train, augment=False)


test_ds, img_count_test = data_processing.load_dataset(paths,"TEST", IMG_SIZE_HEIGHT, IMG_SIZE_WIDTH, HALF, MAX_IMG_TEST)
test_ds = data_processing.dataset_processing(test_ds, cache=True, shuffle = False, batch_size=BATCH_SIZE, prefetch=True, img_count=img_count_test, augment=False)

test_hard_ds, img_count_test_hard = data_processing.load_dataset(paths,"TEST_HARD", IMG_SIZE_HEIGHT, IMG_SIZE_WIDTH, HALF, MAX_IMG_TEST)
test_hard_ds = data_processing.dataset_processing(test_hard_ds, cache=False, shuffle=False, batch_size=BATCH_SIZE,
                                                  prefetch=False, img_count=img_count_test_hard, augment=False)

test_img_ds, img_count_test_img = data_processing.load_dataset(paths,"IMG_ONLY", IMG_SIZE_HEIGHT, IMG_SIZE_WIDTH, HALF, MAX_IMG_TEST, has_mask=False)
test_img_ds = data_processing.dataset_processing(test_img_ds, cache=False, shuffle=False, batch_size=6, 
                                                 prefetch=False, img_count=img_count_test_img, augment=False)

if not os.path.exists(os.path.join(paths["FIGURES"],"PRE_TRAINING")):
    os.makedirs(os.path.join(paths["FIGURES"],"PRE_TRAINING"))
    os.makedirs(os.path.join(paths["FIGURES"],"POST_TRAINING"))
# Out:
# MODEL
# CKPT
# TBLOGS
# TFLITE
# FIGURES
# 2022-06-08 10:38:35.600664: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-08 10:38:35.612778: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-08 10:38:35.612997: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-08 10:38:35.613916: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-06-08 10:38:35.614533: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-08 10:38:35.614687: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-08 10:38:35.614797: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-08 10:38:35.999769: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-08 10:38:35.999888: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-08 10:38:35.999970: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-08 10:38:36.000023: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2022-06-08 10:38:36.000048: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5497 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060, pci bus id: 0000:22:00.0, compute capability: 8.6
# The TRAIN Dataset contains 80 images.
# The TEST Dataset contains 25 images.
# The TEST_HARD Dataset contains 10 images.
# The IMG_ONLY Dataset contains 10 images.

# %%
if TRAIN_MODEL:

    for image,label in train_ds.take(1):
        sample_image, sample_mask = image,label

        #visualize.plot_images(images=sample_image, labels=sample_mask, predictions=None, save=False, batch_size=BATCH_SIZE)
        visualize.plot_images(images=sample_image, labels=None, predictions=None, save=False, batch_size=BATCH_SIZE)

    #for image,label in train_ds_2.take(2):
    #    sample_image, sample_mask = image,label
    #
    #    #visualize.plot_images(images=sample_image, labels=sample_mask, predictions=None, save=False, batch_size=BATCH_SIZE)
    #    visualize.plot_images(images=sample_image, labels=None, predictions=None, save=False, batch_size=BATCH_SIZE)
# Out:
# 2022-06-08 10:38:38.113277: W tensorflow/core/kernels/data/cache_dataset_ops.cc:768] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset  will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.

# %% [markdown]
# # Model

# %%
if weighted_multi_label_sigmoid_edge_loss:
    loss = lambda y_true, y_pred : losses.weighted_multi_label_sigmoid_loss(y_true,y_pred,beta_lower=beta_lower,beta_upper=beta_upper, class_weighted=class_weighted)
elif focal_loss:
    loss = lambda y_true, y_pred : losses.focal_loss_edges(y_true, y_pred, gamma=gamma, alpha=alpha, weighted_beta=weighted_beta,beta_lower=beta_lower,beta_upper=beta_upper, class_weighted=class_weighted)
else:
    raise ValueError("either FocalLoss or WeightedMultiLabelSigmoidLoss must be True")
    

custom_objects = {"BinaryAccuracyEdges": metrics.BinaryAccuracyEdges,
                  "F1Edges": metrics.F1Edges,
                  "<lambda>":loss}

model = tf.keras.models.load_model(paths["MODEL LOADED"], custom_objects=custom_objects)


inputs = tf.keras.Input(shape=(IMG_SIZE_HEIGHT, IMG_SIZE_WIDTH, 3))
outputs = model(inputs, training=False)
model = tf.keras.Model(inputs, outputs)

# %% [markdown]
# # Metric Numerical Results before Fine Tuning on Real World Data

# %% [markdown]
# ## test

# %%
if not TRAIN_MODEL:

    step_width = 0.025
    threshold_range = [0.025,0.975]
    threshold_array = np.arange(threshold_range[0],threshold_range[1]+step_width,step_width)

    path_metrics_evaluation_plot = os.path.join(paths["FIGURES"],"PRE_TRAINING", "metric_test_threshold{:.1f}.svg".format(0))
    threshold_MF_test = visualize.plot_threshold_metrics_evaluation_class(model=model, 
                                                                          ds=test_ds, 
                                                                          num_classes=NUM_CLASSES, 
                                                                          threshold_array=threshold_array, 
                                                                          threshold_edge_width=0, 
                                                                          save=SAVE, 
                                                                          path=path_metrics_evaluation_plot,)

    path_metrics_evaluation_plot = os.path.join(paths["FIGURES"],"PRE_TRAINING", "metric_test_threshold{:.1f}.svg".format(THRESHOLD_EDGE_WIDTH_REAL))
    visualize.plot_threshold_metrics_evaluation_class(model=model, 
                                                      ds=test_ds,
                                                      num_classes=NUM_CLASSES,
                                                      threshold_array=threshold_array, 
                                                      threshold_edge_width=THRESHOLD_EDGE_WIDTH_REAL, 
                                                      save=SAVE, 
                                                      path=path_metrics_evaluation_plot,)

# %% [markdown]
# ## test hard

# %% [markdown]
# if not TRAIN_MODEL:
#     step_width = 0.05
#     threshold_range = [0.05,0.95]
#     threshold_array = np.arange(threshold_range[0],threshold_range[1]+step_width,step_width)
#
#     path_metrics_evaluation_plot = os.path.join(paths["FIGURES"],"PRE_TRAINING", "metric_test_hard_threshold{:.1f}.svg".format(0))
#     threshold_MF_test_hard = visualize.plot_threshold_metrics_evaluation_class(model=model,
#                                                                           ds=test_hard_ds,
#                                                                           num_classes=NUM_CLASSES,
#                                                                           threshold_array=threshold_array,
#                                                                           threshold_edge_width=0,
#                                                                           save=SAVE,
#                                                                           path=path_metrics_evaluation_plot)
#
#     path_metrics_evaluation_plot = os.path.join(paths["FIGURES"],"PRE_TRAINING", "metric_test_hard_threshold{:.1f}.svg".format(THRESHOLD_EDGE_WIDTH_REAL))
#     visualize.plot_threshold_metrics_evaluation_class(model=model,
#                                                       ds=test_ds,
#                                                       num_classes=NUM_CLASSES,
#                                                       threshold_array=threshold_array,
#                                                       threshold_edge_width=THRESHOLD_EDGE_WIDTH_REAL,
#                                                       save=SAVE,
#                                                       path=path_metrics_evaluation_plot)

# %% [markdown]
# # Visual Results before Fine Tuning on Real World Data

# %% [markdown]
# ## test dataset

# %%
if not TRAIN_MODEL:
    i = 1

    for img, label in test_ds.take(3):
        img, label = img, label

        threshold = 0.5

        predictions = model.predict(img)
        predictions = tools.predict_class_postprocessing(predictions, threshold = threshold)

        path = os.path.join(paths["FIGURES"],"PRE_TRAINING", "images_test_threshold{:.2f}_{}".format(threshold,i))
        visualize.plot_images(images=img, labels=label, predictions=predictions, save=SAVE, path=path, batch_size=BATCH_SIZE)

        threshold = threshold_MF_test
        
        predictions = model.predict(img)    
        predictions = tools.predict_class_postprocessing(predictions, threshold = threshold)

        path = os.path.join(paths["FIGURES"],"PRE_TRAINING", "images_test_ods_{}".format(i))
        visualize.plot_images(images=img, labels=label, predictions=predictions, save=SAVE, path=path, batch_size=BATCH_SIZE)

        i += 1

# %% [markdown]
# ## test hard

# %%
if not TRAIN_MODEL:
    i = 1
    for img, label in test_hard_ds.take(2):
        img, label = img, label

        threshold = 0.5

        predictions = model.predict(img)    
        predictions = tools.predict_class_postprocessing(predictions, threshold = threshold)

        path = os.path.join(paths["FIGURES"],"PRE_TRAINING", "images_test_hard_threshold{:.2f}_{}".format(threshold, i))
        visualize.plot_images(images=img, labels=label, predictions=predictions, save=SAVE, path=path, batch_size=BATCH_SIZE)

        threshold = threshold_MF_test

        predictions = model.predict(img)    
        predictions = tools.predict_class_postprocessing(predictions, threshold = threshold)

        path = os.path.join(paths["FIGURES"],"PRE_TRAINING", "images_test_hard_ods_{}".format(threshold, i))
        visualize.plot_images(images=img, labels=label, predictions=predictions, save=SAVE, path=path, batch_size=BATCH_SIZE)

        i += 1

# %% [markdown]
# ## test img

# %%
if not TRAIN_MODEL:
    for img in test_img_ds.take(1):
        img = img

    #threshold = threshold_MF_test
    threshold = [0.4, 0.35, 0.35]
    predictions = model.predict(img)    
    predictions = tools.predict_class_postprocessing(predictions, threshold = threshold)

    path = os.path.join(paths["FIGURES"],"PRE_TRAINING", "images_test_img")
    try:
        visualize.plot_images(images=img, labels=None, predictions=predictions, save=SAVE, path=path, batch_size=6)
    except:
        visualize.plot_images(images=img, labels=None, predictions=predictions, save=SAVE, path=path, batch_size=img_count_test_img)

# %% [markdown]
# # Compile and Train Model

# %%
if TENSORBOARD:
    # %load_ext tensorboard
    # %tensorboard --logdir /home/david/SemesterProject/Models/CASENet/logs

# %%
if TRAIN_MODEL:
    # Fine-tune from this layer onwards
    output_names = ["Conv1", "expanded_conv_project_BN", "block_2_add", "block_5_add", "block_9_add", "block_12_add", "block_15_add", "block_16_project_BN", "out_relu"]
    fine_tune_output = output_names[TRAINABLE_IDX]

    model.trainable = True

    # Freeze all the layers before the `fine_tune_at` layer: 
    for m in model.layers:
        if m.name == "model":
            for submodel in m.layers:
                if submodel.name == "base_model":
                    for layer in submodel.layers[0:100]:
                        layer.trainable = False
                        if layer.name == fine_tune_output:
                            break

# %%
if TRAIN_MODEL:         

    # learning rate schedule
    base_learning_rate = 0.0005
    end_learning_rate = 0.00005
    decay_step = np.ceil(img_count_train / BATCH_SIZE)*EPOCHS
    lr_schedule = tf.keras.optimizers.schedules.PolynomialDecay(base_learning_rate,decay_steps = decay_step,end_learning_rate = end_learning_rate, power = 0.9)

    frequency = int(np.ceil(img_count_train / BATCH_SIZE)*MODEL_SAVE_EPOCH_FREQ)+1

    logdir = os.path.join(paths['TBLOGS'], datetime.now().strftime("%Y%m%d-%H%M%S"))
    callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath = paths["CKPT"]+ "/ckpt-loss={val_loss:.2f}-epoch={epoch:.2f}-f1={val_f1:.4f}",
                                                    save_weights_only=False,save_best_only=False,monitor="val_f1",verbose=1,save_freq= 'epoch', period=10),
                tf.keras.callbacks.TensorBoard(log_dir=logdir,histogram_freq=1)]

    # compile model
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule),
                  loss=loss,
                  metrics=[metrics.BinaryAccuracyEdges(threshold_prediction=0),
                           metrics.F1Edges(threshold_prediction=0, threshold_edge_width=0)])

    evaluate_test = model.evaluate(test_ds, return_dict = True, batch_size = 3)
    evaluate_train = model.evaluate(train_ds, return_dict = True, batch_size = 3)

    history = model.fit(train_ds, epochs=EPOCHS, validation_data=test_ds, callbacks=callbacks, verbose = 1)

    dict_keys = ['loss', 'accuracy_edges', 'f1', 'precision', 'recall']
    for key in dict_keys:
        history.history[key] = [evaluate_train[key]] + history.history[key]
        history.history['val_'+key] = [evaluate_test[key]] + history.history['val_'+key]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# 2022-06-08 10:38:59.221032: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8100
# 7/7 [==============================] - 4s 149ms/step - loss: 246.8946 - accuracy_edges: 0.9962 - f1: 0.4811 - precision: 0.4643 - recall: 0.4992
# 20/20 [==============================] - 6s 225ms/step - loss: 369.6821 - accuracy_edges: 0.9948 - f1: 0.4035 - precision: 0.3563 - recall: 0.4681
# Epoch 1/100
# 20/20 [==============================] - 11s 364ms/step - loss: 362.7421 - accuracy_edges: 0.9955 - f1: 0.3574 - precision: 0.3730 - recall: 0.3503 - val_loss: 190.9056 - val_accuracy_edges: 0.9967 - val_f1: 0.4938 - val_precision: 0.6015 - val_recall: 0.4189
# Epoch 2/100
# 20/20 [==============================] - 8s 396ms/step - loss: 261.0865 - accuracy_edges: 0.9958 - f1: 0.4129 - precision: 0.4363 - recall: 0.3999 - val_loss: 167.3335 - val_accuracy_edges: 0.9970 - val_f1: 0.5388 - val_precision: 0.6432 - val_recall: 0.4635
# Epoch 3/100
# 20/20 [==============================] - 8s 369ms/step - loss: 210.6225 - accuracy_edges: 0.9962 - f1: 0.4937 - precision: 0.5241 - recall: 0.4713 - val_loss: 150.8687 - val_accuracy_edges: 0.9971 - val_f1: 0.5736 - val_precision: 0.6407 - val_recall: 0.5192
# Epoch 4/100
# 20/20 [==============================] - 8s 377ms/step - loss: 185.3271 - accuracy_edges: 0.9966 - f1: 0.5337 - precision: 0.5955 - recall: 0.4857 - val_loss: 143.3243 - val_accuracy_edges: 0.9972 - val_f1: 0.5982 - val_precision: 0.6535 - val_recall: 0.5515
# Epoch 5/100
# 20/20 [==============================] - 8s 385ms/step - loss: 181.3067 - accuracy_edges: 0.9965 - f1: 0.5561 - precision: 0.5865 - recall: 0.5306 - val_loss: 139.5380 - val_accuracy_edges: 0.9972 - val_f1: 0.6022 - val_precision: 0.6581 - val_recall: 0.5551
# Epoch 6/100
# 20/20 [==============================] - 8s 375ms/step - loss: 170.0209 - accuracy_edges: 0.9967 - f1: 0.5667 - precision: 0.6118 - recall: 0.5289 - val_loss: 137.2377 - val_accuracy_edges: 0.9972 - val_f1: 0.6124 - val_precision: 0.6598 - val_recall: 0.5714
# Epoch 7/100
# 20/20 [==============================] - 8s 377ms/step - loss: 170.3794 - accuracy_edges: 0.9966 - f1: 0.5666 - precision: 0.6115 - recall: 0.5287 - val_loss: 134.2593 - val_accuracy_edges: 0.9973 - val_f1: 0.6108 - val_precision: 0.6699 - val_recall: 0.5613
# Epoch 8/100
# 20/20 [==============================] - 8s 369ms/step - loss: 162.6681 - accuracy_edges: 0.9967 - f1: 0.5706 - precision: 0.6186 - recall: 0.5304 - val_loss: 135.0040 - val_accuracy_edges: 0.9973 - val_f1: 0.6155 - val_precision: 0.6790 - val_recall: 0.5628
# Epoch 9/100
# 20/20 [==============================] - 8s 388ms/step - loss: 157.9741 - accuracy_edges: 0.9967 - f1: 0.5723 - precision: 0.6279 - recall: 0.5264 - val_loss: 131.1803 - val_accuracy_edges: 0.9973 - val_f1: 0.6203 - val_precision: 0.6780 - val_recall: 0.5716
# Epoch 10/100
# 20/20 [==============================] - ETA: 0s - loss: 154.3180 - accuracy_edges: 0.9968 - f1: 0.5808 - precision: 0.6340 - recall: 0.5363
# Epoch 10: saving model to /home/david/SemesterProject/Models/SceneNetFloorTiledTextureRandom/SGED_FOCAL_LOSS_0.5_g2_a2_REAL/CKPT/ckpt-loss=130.70-epoch=10.00-f1=0.6182
# 2022-06-08 10:40:36.073939: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# WARNING:absl:Found untraced functions such as reset_state, reset_state while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /home/david/SemesterProject/Models/SceneNetFloorTiledTextureRandom/SGED_FOCAL_LOSS_0.5_g2_a2_REAL/CKPT/ckpt-loss=130.70-epoch=10.00-f1=0.6182/assets
# INFO:tensorflow:Assets written to: /home/david/SemesterProject/Models/SceneNetFloorTiledTextureRandom/SGED_FOCAL_LOSS_0.5_g2_a2_REAL/CKPT/ckpt-loss=130.70-epoch=10.00-f1=0.6182/assets
# 20/20 [==============================] - 20s 1s/step - loss: 154.3180 - accuracy_edges: 0.9968 - f1: 0.5807 - precision: 0.6342 - recall: 0.5361 - val_loss: 130.7008 - val_accuracy_edges: 0.9973 - val_f1: 0.6182 - val_precision: 0.6799 - val_recall: 0.5667
# Epoch 11/100
# 20/20 [==============================] - 8s 373ms/step - loss: 155.0604 - accuracy_edges: 0.9968 - f1: 0.5854 - precision: 0.6466 - recall: 0.5360 - val_loss: 129.8007 - val_accuracy_edges: 0.9974 - val_f1: 0.6240 - val_precision: 0.6813 - val_recall: 0.5755
# Epoch 12/100
# 20/20 [==============================] - 8s 369ms/step - loss: 151.1420 - accuracy_edges: 0.9968 - f1: 0.5909 - precision: 0.6499 - recall: 0.5426 - val_loss: 127.0486 - val_accuracy_edges: 0.9974 - val_f1: 0.6277 - val_precision: 0.6819 - val_recall: 0.5815
# Epoch 13/100
# 20/20 [==============================] - 8s 377ms/step - loss: 151.6841 - accuracy_edges: 0.9968 - f1: 0.5878 - precision: 0.6390 - recall: 0.5455 - val_loss: 129.9041 - val_accuracy_edges: 0.9974 - val_f1: 0.6181 - val_precision: 0.6913 - val_recall: 0.5590
# Epoch 14/100
# 20/20 [==============================] - 8s 373ms/step - loss: 151.1287 - accuracy_edges: 0.9968 - f1: 0.5928 - precision: 0.6436 - recall: 0.5500 - val_loss: 126.7501 - val_accuracy_edges: 0.9974 - val_f1: 0.6284 - val_precision: 0.6869 - val_recall: 0.5791
# Epoch 15/100
# 20/20 [==============================] - 8s 389ms/step - loss: 149.5332 - accuracy_edges: 0.9968 - f1: 0.5879 - precision: 0.6467 - recall: 0.5399 - val_loss: 127.9250 - val_accuracy_edges: 0.9974 - val_f1: 0.6194 - val_precision: 0.6969 - val_recall: 0.5574
# Epoch 16/100
# 20/20 [==============================] - 8s 376ms/step - loss: 150.2607 - accuracy_edges: 0.9968 - f1: 0.5863 - precision: 0.6432 - recall: 0.5398 - val_loss: 126.1949 - val_accuracy_edges: 0.9974 - val_f1: 0.6231 - val_precision: 0.6922 - val_recall: 0.5666
# Epoch 17/100
# 20/20 [==============================] - 8s 380ms/step - loss: 147.9519 - accuracy_edges: 0.9969 - f1: 0.5812 - precision: 0.6654 - recall: 0.5173 - val_loss: 128.5534 - val_accuracy_edges: 0.9974 - val_f1: 0.6181 - val_precision: 0.6998 - val_recall: 0.5535
# Epoch 18/100
# 20/20 [==============================] - 8s 375ms/step - loss: 145.6352 - accuracy_edges: 0.9969 - f1: 0.5996 - precision: 0.6495 - recall: 0.5579 - val_loss: 125.8528 - val_accuracy_edges: 0.9974 - val_f1: 0.6272 - val_precision: 0.6879 - val_recall: 0.5763
# Epoch 19/100
# 20/20 [==============================] - 8s 373ms/step - loss: 144.6964 - accuracy_edges: 0.9969 - f1: 0.5826 - precision: 0.6669 - recall: 0.5186 - val_loss: 123.1536 - val_accuracy_edges: 0.9974 - val_f1: 0.6307 - val_precision: 0.6905 - val_recall: 0.5805
# Epoch 20/100
# 20/20 [==============================] - ETA: 0s - loss: 143.5150 - accuracy_edges: 0.9969 - f1: 0.6076 - precision: 0.6501 - recall: 0.5712
# Epoch 20: saving model to /home/david/SemesterProject/Models/SceneNetFloorTiledTextureRandom/SGED_FOCAL_LOSS_0.5_g2_a2_REAL/CKPT/ckpt-loss=125.41-epoch=20.00-f1=0.6248
# WARNING:absl:Found untraced functions such as reset_state, reset_state while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /home/david/SemesterProject/Models/SceneNetFloorTiledTextureRandom/SGED_FOCAL_LOSS_0.5_g2_a2_REAL/CKPT/ckpt-loss=125.41-epoch=20.00-f1=0.6248/assets
# INFO:tensorflow:Assets written to: /home/david/SemesterProject/Models/SceneNetFloorTiledTextureRandom/SGED_FOCAL_LOSS_0.5_g2_a2_REAL/CKPT/ckpt-loss=125.41-epoch=20.00-f1=0.6248/assets
# 20/20 [==============================] - 20s 986ms/step - loss: 143.5150 - accuracy_edges: 0.9969 - f1: 0.6070 - precision: 0.6500 - recall: 0.5702 - val_loss: 125.4131 - val_accuracy_edges: 0.9974 - val_f1: 0.6248 - val_precision: 0.6932 - val_recall: 0.5687
# Epoch 21/100
# 20/20 [==============================] - 8s 370ms/step - loss: 141.7877 - accuracy_edges: 0.9969 - f1: 0.5903 - precision: 0.6616 - recall: 0.5337 - val_loss: 123.7600 - val_accuracy_edges: 0.9974 - val_f1: 0.6279 - val_precision: 0.7005 - val_recall: 0.5689
# Epoch 22/100
# 20/20 [==============================] - 8s 370ms/step - loss: 139.6478 - accuracy_edges: 0.9969 - f1: 0.5990 - precision: 0.6637 - recall: 0.5467 - val_loss: 122.3967 - val_accuracy_edges: 0.9974 - val_f1: 0.6345 - val_precision: 0.6929 - val_recall: 0.5852
# Epoch 23/100
# 20/20 [==============================] - 8s 369ms/step - loss: 138.6695 - accuracy_edges: 0.9969 - f1: 0.5958 - precision: 0.6640 - recall: 0.5411 - val_loss: 121.5736 - val_accuracy_edges: 0.9974 - val_f1: 0.6298 - val_precision: 0.7005 - val_recall: 0.5720
# Epoch 24/100
# 20/20 [==============================] - 8s 384ms/step - loss: 138.9810 - accuracy_edges: 0.9970 - f1: 0.6043 - precision: 0.6709 - recall: 0.5504 - val_loss: 120.6481 - val_accuracy_edges: 0.9974 - val_f1: 0.6382 - val_precision: 0.6920 - val_recall: 0.5922
# Epoch 25/100
# 20/20 [==============================] - 8s 375ms/step - loss: 137.9289 - accuracy_edges: 0.9969 - f1: 0.6117 - precision: 0.6652 - recall: 0.5672 - val_loss: 122.2272 - val_accuracy_edges: 0.9974 - val_f1: 0.6275 - val_precision: 0.7030 - val_recall: 0.5666
# Epoch 26/100
# 20/20 [==============================] - 8s 375ms/step - loss: 137.9379 - accuracy_edges: 0.9970 - f1: 0.6024 - precision: 0.6639 - recall: 0.5523 - val_loss: 121.7228 - val_accuracy_edges: 0.9974 - val_f1: 0.6278 - val_precision: 0.7049 - val_recall: 0.5658
# Epoch 27/100
# 20/20 [==============================] - 8s 375ms/step - loss: 138.4012 - accuracy_edges: 0.9969 - f1: 0.5913 - precision: 0.6678 - recall: 0.5321 - val_loss: 121.9829 - val_accuracy_edges: 0.9975 - val_f1: 0.6358 - val_precision: 0.6994 - val_recall: 0.5828
# Epoch 28/100
# 20/20 [==============================] - 8s 373ms/step - loss: 136.9726 - accuracy_edges: 0.9970 - f1: 0.6156 - precision: 0.6652 - recall: 0.5735 - val_loss: 120.9915 - val_accuracy_edges: 0.9974 - val_f1: 0.6282 - val_precision: 0.7062 - val_recall: 0.5657
# Epoch 29/100
# 20/20 [==============================] - 8s 376ms/step - loss: 137.2541 - accuracy_edges: 0.9969 - f1: 0.5899 - precision: 0.6667 - recall: 0.5299 - val_loss: 120.6582 - val_accuracy_edges: 0.9974 - val_f1: 0.6305 - val_precision: 0.7011 - val_recall: 0.5727
# Epoch 30/100
# 20/20 [==============================] - ETA: 0s - loss: 135.9052 - accuracy_edges: 0.9970 - f1: 0.6071 - precision: 0.6713 - recall: 0.5550
# Epoch 30: saving model to /home/david/SemesterProject/Models/SceneNetFloorTiledTextureRandom/SGED_FOCAL_LOSS_0.5_g2_a2_REAL/CKPT/ckpt-loss=119.78-epoch=30.00-f1=0.6386
# WARNING:absl:Found untraced functions such as reset_state, reset_state while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /home/david/SemesterProject/Models/SceneNetFloorTiledTextureRandom/SGED_FOCAL_LOSS_0.5_g2_a2_REAL/CKPT/ckpt-loss=119.78-epoch=30.00-f1=0.6386/assets
# INFO:tensorflow:Assets written to: /home/david/SemesterProject/Models/SceneNetFloorTiledTextureRandom/SGED_FOCAL_LOSS_0.5_g2_a2_REAL/CKPT/ckpt-loss=119.78-epoch=30.00-f1=0.6386/assets
# 20/20 [==============================] - 20s 1s/step - loss: 135.9052 - accuracy_edges: 0.9970 - f1: 0.6067 - precision: 0.6711 - recall: 0.5544 - val_loss: 119.7827 - val_accuracy_edges: 0.9974 - val_f1: 0.6386 - val_precision: 0.6940 - val_recall: 0.5914
# Epoch 31/100
# 20/20 [==============================] - 8s 373ms/step - loss: 136.6013 - accuracy_edges: 0.9970 - f1: 0.6156 - precision: 0.6633 - recall: 0.5753 - val_loss: 121.3124 - val_accuracy_edges: 0.9974 - val_f1: 0.6293 - val_precision: 0.7066 - val_recall: 0.5672
# Epoch 32/100
# 20/20 [==============================] - 8s 370ms/step - loss: 138.4896 - accuracy_edges: 0.9970 - f1: 0.6063 - precision: 0.6678 - recall: 0.5557 - val_loss: 119.3525 - val_accuracy_edges: 0.9975 - val_f1: 0.6404 - val_precision: 0.6953 - val_recall: 0.5935
# Epoch 33/100
# 20/20 [==============================] - 8s 377ms/step - loss: 137.2560 - accuracy_edges: 0.9969 - f1: 0.6022 - precision: 0.6614 - recall: 0.5540 - val_loss: 121.8147 - val_accuracy_edges: 0.9975 - val_f1: 0.6271 - val_precision: 0.7132 - val_recall: 0.5596
# Epoch 34/100
# 20/20 [==============================] - 8s 366ms/step - loss: 137.0687 - accuracy_edges: 0.9970 - f1: 0.6173 - precision: 0.6685 - recall: 0.5739 - val_loss: 118.9539 - val_accuracy_edges: 0.9975 - val_f1: 0.6364 - val_precision: 0.7019 - val_recall: 0.5820
# Epoch 35/100
# 20/20 [==============================] - 8s 379ms/step - loss: 135.3986 - accuracy_edges: 0.9970 - f1: 0.5950 - precision: 0.6657 - recall: 0.5398 - val_loss: 119.2242 - val_accuracy_edges: 0.9975 - val_f1: 0.6339 - val_precision: 0.7091 - val_recall: 0.5730
# Epoch 36/100
# 20/20 [==============================] - 8s 388ms/step - loss: 134.9961 - accuracy_edges: 0.9970 - f1: 0.5997 - precision: 0.6801 - recall: 0.5372 - val_loss: 117.8516 - val_accuracy_edges: 0.9975 - val_f1: 0.6469 - val_precision: 0.6988 - val_recall: 0.6022
# Epoch 37/100
# 20/20 [==============================] - 8s 373ms/step - loss: 133.1619 - accuracy_edges: 0.9970 - f1: 0.6208 - precision: 0.6623 - recall: 0.5846 - val_loss: 122.3625 - val_accuracy_edges: 0.9975 - val_f1: 0.6292 - val_precision: 0.7121 - val_recall: 0.5636
# Epoch 38/100
# 20/20 [==============================] - 8s 381ms/step - loss: 134.1205 - accuracy_edges: 0.9970 - f1: 0.6147 - precision: 0.6731 - recall: 0.5663 - val_loss: 118.9627 - val_accuracy_edges: 0.9975 - val_f1: 0.6347 - val_precision: 0.7071 - val_recall: 0.5758
# Epoch 39/100
# 20/20 [==============================] - 8s 365ms/step - loss: 136.9745 - accuracy_edges: 0.9970 - f1: 0.6002 - precision: 0.6756 - recall: 0.5416 - val_loss: 118.3876 - val_accuracy_edges: 0.9975 - val_f1: 0.6435 - val_precision: 0.7016 - val_recall: 0.5942
# Epoch 40/100
# 20/20 [==============================] - ETA: 0s - loss: 134.8516 - accuracy_edges: 0.9970 - f1: 0.6214 - precision: 0.6662 - recall: 0.5830
# Epoch 40: saving model to /home/david/SemesterProject/Models/SceneNetFloorTiledTextureRandom/SGED_FOCAL_LOSS_0.5_g2_a2_REAL/CKPT/ckpt-loss=119.51-epoch=40.00-f1=0.6324
# WARNING:absl:Found untraced functions such as reset_state, reset_state while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /home/david/SemesterProject/Models/SceneNetFloorTiledTextureRandom/SGED_FOCAL_LOSS_0.5_g2_a2_REAL/CKPT/ckpt-loss=119.51-epoch=40.00-f1=0.6324/assets
# INFO:tensorflow:Assets written to: /home/david/SemesterProject/Models/SceneNetFloorTiledTextureRandom/SGED_FOCAL_LOSS_0.5_g2_a2_REAL/CKPT/ckpt-loss=119.51-epoch=40.00-f1=0.6324/assets
# 20/20 [==============================] - 21s 1s/step - loss: 134.8516 - accuracy_edges: 0.9970 - f1: 0.6205 - precision: 0.6660 - recall: 0.5815 - val_loss: 119.5125 - val_accuracy_edges: 0.9975 - val_f1: 0.6324 - val_precision: 0.7073 - val_recall: 0.5719
# Epoch 41/100
# 20/20 [==============================] - 8s 391ms/step - loss: 133.1559 - accuracy_edges: 0.9970 - f1: 0.6060 - precision: 0.6669 - recall: 0.5560 - val_loss: 120.2895 - val_accuracy_edges: 0.9975 - val_f1: 0.6284 - val_precision: 0.7140 - val_recall: 0.5611
# Epoch 42/100
# 20/20 [==============================] - 8s 371ms/step - loss: 132.4234 - accuracy_edges: 0.9970 - f1: 0.5979 - precision: 0.6805 - recall: 0.5343 - val_loss: 117.6643 - val_accuracy_edges: 0.9975 - val_f1: 0.6442 - val_precision: 0.7049 - val_recall: 0.5931
# Epoch 43/100
# 20/20 [==============================] - 8s 381ms/step - loss: 132.6229 - accuracy_edges: 0.9970 - f1: 0.6142 - precision: 0.6668 - recall: 0.5697 - val_loss: 119.2681 - val_accuracy_edges: 0.9975 - val_f1: 0.6367 - val_precision: 0.7075 - val_recall: 0.5787
# Epoch 44/100
# 20/20 [==============================] - 8s 365ms/step - loss: 132.1915 - accuracy_edges: 0.9970 - f1: 0.6205 - precision: 0.6781 - recall: 0.5722 - val_loss: 118.8034 - val_accuracy_edges: 0.9975 - val_f1: 0.6342 - val_precision: 0.7111 - val_recall: 0.5723
# Epoch 45/100
# 20/20 [==============================] - 8s 367ms/step - loss: 133.9518 - accuracy_edges: 0.9970 - f1: 0.6128 - precision: 0.6716 - recall: 0.5641 - val_loss: 117.7219 - val_accuracy_edges: 0.9975 - val_f1: 0.6399 - val_precision: 0.7031 - val_recall: 0.5871
# Epoch 46/100
# 20/20 [==============================] - 8s 385ms/step - loss: 134.0439 - accuracy_edges: 0.9970 - f1: 0.6020 - precision: 0.6756 - recall: 0.5436 - val_loss: 118.4322 - val_accuracy_edges: 0.9975 - val_f1: 0.6391 - val_precision: 0.7053 - val_recall: 0.5842
# Epoch 47/100
# 20/20 [==============================] - 8s 376ms/step - loss: 132.4626 - accuracy_edges: 0.9970 - f1: 0.6171 - precision: 0.6639 - recall: 0.5769 - val_loss: 119.4365 - val_accuracy_edges: 0.9975 - val_f1: 0.6305 - val_precision: 0.7171 - val_recall: 0.5626
# Epoch 48/100
# 20/20 [==============================] - 8s 375ms/step - loss: 131.8030 - accuracy_edges: 0.9970 - f1: 0.6063 - precision: 0.6765 - recall: 0.5497 - val_loss: 117.1081 - val_accuracy_edges: 0.9975 - val_f1: 0.6422 - val_precision: 0.7090 - val_recall: 0.5870
# Epoch 49/100
# 20/20 [==============================] - 8s 392ms/step - loss: 130.8082 - accuracy_edges: 0.9970 - f1: 0.6050 - precision: 0.6690 - recall: 0.5527 - val_loss: 120.0497 - val_accuracy_edges: 0.9975 - val_f1: 0.6353 - val_precision: 0.7107 - val_recall: 0.5743
# Epoch 50/100
# 20/20 [==============================] - ETA: 0s - loss: 132.5754 - accuracy_edges: 0.9970 - f1: 0.6193 - precision: 0.6772 - recall: 0.5708
# Epoch 50: saving model to /home/david/SemesterProject/Models/SceneNetFloorTiledTextureRandom/SGED_FOCAL_LOSS_0.5_g2_a2_REAL/CKPT/ckpt-loss=116.93-epoch=50.00-f1=0.6432
# WARNING:absl:Found untraced functions such as reset_state, reset_state while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /home/david/SemesterProject/Models/SceneNetFloorTiledTextureRandom/SGED_FOCAL_LOSS_0.5_g2_a2_REAL/CKPT/ckpt-loss=116.93-epoch=50.00-f1=0.6432/assets
# INFO:tensorflow:Assets written to: /home/david/SemesterProject/Models/SceneNetFloorTiledTextureRandom/SGED_FOCAL_LOSS_0.5_g2_a2_REAL/CKPT/ckpt-loss=116.93-epoch=50.00-f1=0.6432/assets
# 20/20 [==============================] - 21s 1s/step - loss: 132.5754 - accuracy_edges: 0.9970 - f1: 0.6189 - precision: 0.6768 - recall: 0.5704 - val_loss: 116.9316 - val_accuracy_edges: 0.9975 - val_f1: 0.6432 - val_precision: 0.7088 - val_recall: 0.5887
# Epoch 51/100
# 20/20 [==============================] - 8s 380ms/step - loss: 130.8029 - accuracy_edges: 0.9970 - f1: 0.6136 - precision: 0.6812 - recall: 0.5593 - val_loss: 118.7411 - val_accuracy_edges: 0.9975 - val_f1: 0.6408 - val_precision: 0.7074 - val_recall: 0.5857
# Epoch 52/100
# 20/20 [==============================] - 8s 373ms/step - loss: 129.3074 - accuracy_edges: 0.9970 - f1: 0.6276 - precision: 0.6752 - recall: 0.5866 - val_loss: 118.3816 - val_accuracy_edges: 0.9975 - val_f1: 0.6369 - val_precision: 0.7116 - val_recall: 0.5764
# Epoch 53/100
# 20/20 [==============================] - 8s 386ms/step - loss: 130.6741 - accuracy_edges: 0.9970 - f1: 0.6223 - precision: 0.6727 - recall: 0.5794 - val_loss: 119.2573 - val_accuracy_edges: 0.9975 - val_f1: 0.6346 - val_precision: 0.7129 - val_recall: 0.5719
# Epoch 54/100
# 20/20 [==============================] - 8s 388ms/step - loss: 132.6098 - accuracy_edges: 0.9970 - f1: 0.6144 - precision: 0.6778 - recall: 0.5624 - val_loss: 117.0069 - val_accuracy_edges: 0.9975 - val_f1: 0.6492 - val_precision: 0.7040 - val_recall: 0.6024
# Epoch 55/100
# 20/20 [==============================] - 8s 372ms/step - loss: 133.6572 - accuracy_edges: 0.9970 - f1: 0.6223 - precision: 0.6762 - recall: 0.5770 - val_loss: 118.8534 - val_accuracy_edges: 0.9975 - val_f1: 0.6352 - val_precision: 0.7176 - val_recall: 0.5698
# Epoch 56/100
# 20/20 [==============================] - 11s 560ms/step - loss: 132.9823 - accuracy_edges: 0.9970 - f1: 0.6133 - precision: 0.6750 - recall: 0.5626 - val_loss: 124.1417 - val_accuracy_edges: 0.9975 - val_f1: 0.6295 - val_precision: 0.7168 - val_recall: 0.5612
# Epoch 57/100
# 20/20 [==============================] - 12s 585ms/step - loss: 130.4799 - accuracy_edges: 0.9970 - f1: 0.6074 - precision: 0.6794 - recall: 0.5499 - val_loss: 118.2678 - val_accuracy_edges: 0.9975 - val_f1: 0.6420 - val_precision: 0.7096 - val_recall: 0.5862
# Epoch 58/100
# 20/20 [==============================] - 9s 407ms/step - loss: 131.1501 - accuracy_edges: 0.9970 - f1: 0.6121 - precision: 0.6840 - recall: 0.5545 - val_loss: 119.0799 - val_accuracy_edges: 0.9975 - val_f1: 0.6404 - val_precision: 0.7097 - val_recall: 0.5835
# Epoch 59/100
# 20/20 [==============================] - 9s 412ms/step - loss: 129.6188 - accuracy_edges: 0.9970 - f1: 0.6290 - precision: 0.6710 - recall: 0.5923 - val_loss: 118.9591 - val_accuracy_edges: 0.9975 - val_f1: 0.6332 - val_precision: 0.7194 - val_recall: 0.5655
# Epoch 60/100
# 20/20 [==============================] - ETA: 0s - loss: 128.6446 - accuracy_edges: 0.9970 - f1: 0.6103 - precision: 0.6768 - recall: 0.5562
# Epoch 60: saving model to /home/david/SemesterProject/Models/SceneNetFloorTiledTextureRandom/SGED_FOCAL_LOSS_0.5_g2_a2_REAL/CKPT/ckpt-loss=117.73-epoch=60.00-f1=0.6386
# WARNING:absl:Found untraced functions such as reset_state, reset_state while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /home/david/SemesterProject/Models/SceneNetFloorTiledTextureRandom/SGED_FOCAL_LOSS_0.5_g2_a2_REAL/CKPT/ckpt-loss=117.73-epoch=60.00-f1=0.6386/assets
# INFO:tensorflow:Assets written to: /home/david/SemesterProject/Models/SceneNetFloorTiledTextureRandom/SGED_FOCAL_LOSS_0.5_g2_a2_REAL/CKPT/ckpt-loss=117.73-epoch=60.00-f1=0.6386/assets
# 20/20 [==============================] - 23s 1s/step - loss: 128.6446 - accuracy_edges: 0.9970 - f1: 0.6105 - precision: 0.6765 - recall: 0.5567 - val_loss: 117.7306 - val_accuracy_edges: 0.9975 - val_f1: 0.6386 - val_precision: 0.7142 - val_recall: 0.5774
# Epoch 61/100
# 20/20 [==============================] - 8s 386ms/step - loss: 129.5550 - accuracy_edges: 0.9971 - f1: 0.6142 - precision: 0.6827 - recall: 0.5586 - val_loss: 118.3289 - val_accuracy_edges: 0.9975 - val_f1: 0.6366 - val_precision: 0.7122 - val_recall: 0.5755
# Epoch 62/100
# 20/20 [==============================] - 8s 398ms/step - loss: 130.2103 - accuracy_edges: 0.9970 - f1: 0.6164 - precision: 0.6722 - recall: 0.5697 - val_loss: 117.6636 - val_accuracy_edges: 0.9975 - val_f1: 0.6413 - val_precision: 0.7088 - val_recall: 0.5856
# Epoch 63/100
# 20/20 [==============================] - 8s 358ms/step - loss: 129.4772 - accuracy_edges: 0.9970 - f1: 0.6163 - precision: 0.6742 - recall: 0.5679 - val_loss: 117.0098 - val_accuracy_edges: 0.9975 - val_f1: 0.6353 - val_precision: 0.7131 - val_recall: 0.5728
# Epoch 64/100
# 20/20 [==============================] - 8s 409ms/step - loss: 128.6040 - accuracy_edges: 0.9970 - f1: 0.6170 - precision: 0.6784 - recall: 0.5662 - val_loss: 118.1154 - val_accuracy_edges: 0.9975 - val_f1: 0.6335 - val_precision: 0.7163 - val_recall: 0.5679
# Epoch 65/100
# 20/20 [==============================] - 9s 412ms/step - loss: 130.1868 - accuracy_edges: 0.9970 - f1: 0.6225 - precision: 0.6749 - recall: 0.5781 - val_loss: 117.1503 - val_accuracy_edges: 0.9975 - val_f1: 0.6440 - val_precision: 0.7035 - val_recall: 0.5938
# Epoch 66/100
# 20/20 [==============================] - 9s 412ms/step - loss: 129.8118 - accuracy_edges: 0.9970 - f1: 0.6266 - precision: 0.6740 - recall: 0.5858 - val_loss: 118.9396 - val_accuracy_edges: 0.9975 - val_f1: 0.6329 - val_precision: 0.7144 - val_recall: 0.5680
# Epoch 67/100
# 20/20 [==============================] - 8s 409ms/step - loss: 129.6000 - accuracy_edges: 0.9970 - f1: 0.6044 - precision: 0.6828 - recall: 0.5425 - val_loss: 117.7349 - val_accuracy_edges: 0.9975 - val_f1: 0.6384 - val_precision: 0.7125 - val_recall: 0.5782
# Epoch 68/100
# 20/20 [==============================] - 13s 659ms/step - loss: 128.8217 - accuracy_edges: 0.9971 - f1: 0.6259 - precision: 0.6778 - recall: 0.5820 - val_loss: 117.6015 - val_accuracy_edges: 0.9975 - val_f1: 0.6385 - val_precision: 0.7095 - val_recall: 0.5804
# Epoch 69/100
# 20/20 [==============================] - 13s 655ms/step - loss: 129.1784 - accuracy_edges: 0.9971 - f1: 0.6168 - precision: 0.6790 - recall: 0.5655 - val_loss: 116.4772 - val_accuracy_edges: 0.9975 - val_f1: 0.6418 - val_precision: 0.7103 - val_recall: 0.5854
# Epoch 70/100
# 20/20 [==============================] - ETA: 0s - loss: 128.4083 - accuracy_edges: 0.9971 - f1: 0.6299 - precision: 0.6776 - recall: 0.5888
# Epoch 70: saving model to /home/david/SemesterProject/Models/SceneNetFloorTiledTextureRandom/SGED_FOCAL_LOSS_0.5_g2_a2_REAL/CKPT/ckpt-loss=118.55-epoch=70.00-f1=0.6364
# WARNING:absl:Found untraced functions such as reset_state, reset_state while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /home/david/SemesterProject/Models/SceneNetFloorTiledTextureRandom/SGED_FOCAL_LOSS_0.5_g2_a2_REAL/CKPT/ckpt-loss=118.55-epoch=70.00-f1=0.6364/assets
# INFO:tensorflow:Assets written to: /home/david/SemesterProject/Models/SceneNetFloorTiledTextureRandom/SGED_FOCAL_LOSS_0.5_g2_a2_REAL/CKPT/ckpt-loss=118.55-epoch=70.00-f1=0.6364/assets
# 20/20 [==============================] - 22s 1s/step - loss: 128.4083 - accuracy_edges: 0.9971 - f1: 0.6293 - precision: 0.6773 - recall: 0.5879 - val_loss: 118.5502 - val_accuracy_edges: 0.9975 - val_f1: 0.6364 - val_precision: 0.7109 - val_recall: 0.5760
# Epoch 71/100
# 20/20 [==============================] - 8s 396ms/step - loss: 129.4955 - accuracy_edges: 0.9971 - f1: 0.6153 - precision: 0.6740 - recall: 0.5665 - val_loss: 117.1663 - val_accuracy_edges: 0.9975 - val_f1: 0.6379 - val_precision: 0.7135 - val_recall: 0.5768
# Epoch 72/100
# 20/20 [==============================] - 8s 395ms/step - loss: 128.6528 - accuracy_edges: 0.9970 - f1: 0.6234 - precision: 0.6733 - recall: 0.5806 - val_loss: 117.2949 - val_accuracy_edges: 0.9975 - val_f1: 0.6380 - val_precision: 0.7117 - val_recall: 0.5782
# Epoch 73/100
# 20/20 [==============================] - 8s 370ms/step - loss: 126.7686 - accuracy_edges: 0.9971 - f1: 0.6233 - precision: 0.6829 - recall: 0.5739 - val_loss: 117.5886 - val_accuracy_edges: 0.9975 - val_f1: 0.6370 - val_precision: 0.7130 - val_recall: 0.5756
# Epoch 74/100
# 20/20 [==============================] - 8s 374ms/step - loss: 128.9640 - accuracy_edges: 0.9971 - f1: 0.6222 - precision: 0.6859 - recall: 0.5698 - val_loss: 117.4723 - val_accuracy_edges: 0.9975 - val_f1: 0.6378 - val_precision: 0.7085 - val_recall: 0.5799
# Epoch 75/100
# 20/20 [==============================] - 8s 377ms/step - loss: 128.6469 - accuracy_edges: 0.9971 - f1: 0.6224 - precision: 0.6763 - recall: 0.5769 - val_loss: 117.8994 - val_accuracy_edges: 0.9975 - val_f1: 0.6355 - val_precision: 0.7131 - val_recall: 0.5731
# Epoch 76/100
# 20/20 [==============================] - 8s 378ms/step - loss: 129.2694 - accuracy_edges: 0.9971 - f1: 0.6197 - precision: 0.6802 - recall: 0.5695 - val_loss: 116.7212 - val_accuracy_edges: 0.9975 - val_f1: 0.6430 - val_precision: 0.7090 - val_recall: 0.5883
# Epoch 77/100
# 20/20 [==============================] - 8s 377ms/step - loss: 127.8133 - accuracy_edges: 0.9971 - f1: 0.6264 - precision: 0.6764 - recall: 0.5837 - val_loss: 116.3273 - val_accuracy_edges: 0.9975 - val_f1: 0.6380 - val_precision: 0.7135 - val_recall: 0.5770
# Epoch 78/100
# 20/20 [==============================] - 8s 363ms/step - loss: 127.3592 - accuracy_edges: 0.9971 - f1: 0.6186 - precision: 0.6786 - recall: 0.5687 - val_loss: 117.2447 - val_accuracy_edges: 0.9975 - val_f1: 0.6381 - val_precision: 0.7131 - val_recall: 0.5775
# Epoch 79/100
# 20/20 [==============================] - 8s 372ms/step - loss: 127.6915 - accuracy_edges: 0.9971 - f1: 0.6258 - precision: 0.6781 - recall: 0.5814 - val_loss: 117.8127 - val_accuracy_edges: 0.9975 - val_f1: 0.6404 - val_precision: 0.7128 - val_recall: 0.5813
# Epoch 80/100
# 20/20 [==============================] - ETA: 0s - loss: 128.0187 - accuracy_edges: 0.9970 - f1: 0.6256 - precision: 0.6732 - recall: 0.5844
# Epoch 80: saving model to /home/david/SemesterProject/Models/SceneNetFloorTiledTextureRandom/SGED_FOCAL_LOSS_0.5_g2_a2_REAL/CKPT/ckpt-loss=118.61-epoch=80.00-f1=0.6350
# WARNING:absl:Found untraced functions such as reset_state, reset_state while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /home/david/SemesterProject/Models/SceneNetFloorTiledTextureRandom/SGED_FOCAL_LOSS_0.5_g2_a2_REAL/CKPT/ckpt-loss=118.61-epoch=80.00-f1=0.6350/assets
# INFO:tensorflow:Assets written to: /home/david/SemesterProject/Models/SceneNetFloorTiledTextureRandom/SGED_FOCAL_LOSS_0.5_g2_a2_REAL/CKPT/ckpt-loss=118.61-epoch=80.00-f1=0.6350/assets
# 20/20 [==============================] - 21s 1s/step - loss: 128.0187 - accuracy_edges: 0.9970 - f1: 0.6252 - precision: 0.6730 - recall: 0.5840 - val_loss: 118.6074 - val_accuracy_edges: 0.9975 - val_f1: 0.6350 - val_precision: 0.7164 - val_recall: 0.5701
# Epoch 81/100
# 20/20 [==============================] - 8s 370ms/step - loss: 127.9186 - accuracy_edges: 0.9971 - f1: 0.6125 - precision: 0.6795 - recall: 0.5581 - val_loss: 117.5313 - val_accuracy_edges: 0.9975 - val_f1: 0.6387 - val_precision: 0.7153 - val_recall: 0.5770
# Epoch 82/100
# 20/20 [==============================] - 9s 434ms/step - loss: 126.6978 - accuracy_edges: 0.9971 - f1: 0.6267 - precision: 0.6755 - recall: 0.5846 - val_loss: 117.4331 - val_accuracy_edges: 0.9975 - val_f1: 0.6384 - val_precision: 0.7138 - val_recall: 0.5774
# Epoch 83/100
# 20/20 [==============================] - 12s 552ms/step - loss: 125.9791 - accuracy_edges: 0.9971 - f1: 0.6192 - precision: 0.6823 - recall: 0.5672 - val_loss: 117.4907 - val_accuracy_edges: 0.9975 - val_f1: 0.6407 - val_precision: 0.7120 - val_recall: 0.5824
# Epoch 84/100
# 20/20 [==============================] - 9s 432ms/step - loss: 127.8923 - accuracy_edges: 0.9971 - f1: 0.6260 - precision: 0.6755 - recall: 0.5835 - val_loss: 116.9992 - val_accuracy_edges: 0.9975 - val_f1: 0.6407 - val_precision: 0.7137 - val_recall: 0.5813
# Epoch 85/100
# 20/20 [==============================] - 8s 372ms/step - loss: 127.4633 - accuracy_edges: 0.9971 - f1: 0.6251 - precision: 0.6751 - recall: 0.5822 - val_loss: 116.7569 - val_accuracy_edges: 0.9975 - val_f1: 0.6372 - val_precision: 0.7197 - val_recall: 0.5716
# Epoch 86/100
# 20/20 [==============================] - 8s 369ms/step - loss: 127.1447 - accuracy_edges: 0.9971 - f1: 0.6160 - precision: 0.6858 - recall: 0.5595 - val_loss: 116.4742 - val_accuracy_edges: 0.9975 - val_f1: 0.6422 - val_precision: 0.7126 - val_recall: 0.5844
# Epoch 87/100
# 20/20 [==============================] - 8s 377ms/step - loss: 125.5563 - accuracy_edges: 0.9971 - f1: 0.6312 - precision: 0.6836 - recall: 0.5866 - val_loss: 117.3517 - val_accuracy_edges: 0.9975 - val_f1: 0.6397 - val_precision: 0.7133 - val_recall: 0.5799
# Epoch 88/100
# 20/20 [==============================] - 8s 380ms/step - loss: 126.4030 - accuracy_edges: 0.9971 - f1: 0.6232 - precision: 0.6790 - recall: 0.5765 - val_loss: 116.9279 - val_accuracy_edges: 0.9975 - val_f1: 0.6375 - val_precision: 0.7160 - val_recall: 0.5745
# Epoch 89/100
# 20/20 [==============================] - 8s 366ms/step - loss: 125.7591 - accuracy_edges: 0.9971 - f1: 0.6316 - precision: 0.6824 - recall: 0.5881 - val_loss: 116.0159 - val_accuracy_edges: 0.9975 - val_f1: 0.6412 - val_precision: 0.7125 - val_recall: 0.5829
# Epoch 90/100
# 20/20 [==============================] - ETA: 0s - loss: 125.3311 - accuracy_edges: 0.9971 - f1: 0.6323 - precision: 0.6865 - recall: 0.5864
# Epoch 90: saving model to /home/david/SemesterProject/Models/SceneNetFloorTiledTextureRandom/SGED_FOCAL_LOSS_0.5_g2_a2_REAL/CKPT/ckpt-loss=115.89-epoch=90.00-f1=0.6427
# WARNING:absl:Found untraced functions such as reset_state, reset_state while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /home/david/SemesterProject/Models/SceneNetFloorTiledTextureRandom/SGED_FOCAL_LOSS_0.5_g2_a2_REAL/CKPT/ckpt-loss=115.89-epoch=90.00-f1=0.6427/assets
# INFO:tensorflow:Assets written to: /home/david/SemesterProject/Models/SceneNetFloorTiledTextureRandom/SGED_FOCAL_LOSS_0.5_g2_a2_REAL/CKPT/ckpt-loss=115.89-epoch=90.00-f1=0.6427/assets
# 20/20 [==============================] - 20s 1s/step - loss: 125.3311 - accuracy_edges: 0.9971 - f1: 0.6319 - precision: 0.6863 - recall: 0.5859 - val_loss: 115.8914 - val_accuracy_edges: 0.9975 - val_f1: 0.6427 - val_precision: 0.7133 - val_recall: 0.5848
# Epoch 91/100
# 20/20 [==============================] - 8s 365ms/step - loss: 125.5395 - accuracy_edges: 0.9971 - f1: 0.6310 - precision: 0.6883 - recall: 0.5831 - val_loss: 116.2213 - val_accuracy_edges: 0.9975 - val_f1: 0.6404 - val_precision: 0.7151 - val_recall: 0.5798
# Epoch 92/100
# 20/20 [==============================] - 8s 361ms/step - loss: 128.3748 - accuracy_edges: 0.9971 - f1: 0.6224 - precision: 0.6845 - recall: 0.5711 - val_loss: 115.7845 - val_accuracy_edges: 0.9975 - val_f1: 0.6441 - val_precision: 0.7112 - val_recall: 0.5886
# Epoch 93/100
# 20/20 [==============================] - 8s 372ms/step - loss: 125.1878 - accuracy_edges: 0.9971 - f1: 0.6313 - precision: 0.6771 - recall: 0.5916 - val_loss: 115.5807 - val_accuracy_edges: 0.9975 - val_f1: 0.6416 - val_precision: 0.7150 - val_recall: 0.5818
# Epoch 94/100
# 20/20 [==============================] - 8s 369ms/step - loss: 125.7140 - accuracy_edges: 0.9971 - f1: 0.6226 - precision: 0.6823 - recall: 0.5727 - val_loss: 115.9305 - val_accuracy_edges: 0.9975 - val_f1: 0.6420 - val_precision: 0.7130 - val_recall: 0.5840
# Epoch 95/100
# 20/20 [==============================] - 10s 486ms/step - loss: 125.8519 - accuracy_edges: 0.9971 - f1: 0.6305 - precision: 0.6780 - recall: 0.5893 - val_loss: 116.7604 - val_accuracy_edges: 0.9975 - val_f1: 0.6394 - val_precision: 0.7128 - val_recall: 0.5796
# Epoch 96/100
# 20/20 [==============================] - 11s 547ms/step - loss: 126.8540 - accuracy_edges: 0.9971 - f1: 0.6266 - precision: 0.6803 - recall: 0.5813 - val_loss: 116.3858 - val_accuracy_edges: 0.9975 - val_f1: 0.6405 - val_precision: 0.7128 - val_recall: 0.5815
# Epoch 97/100
# 20/20 [==============================] - 10s 500ms/step - loss: 127.9507 - accuracy_edges: 0.9971 - f1: 0.6221 - precision: 0.6791 - recall: 0.5740 - val_loss: 116.1397 - val_accuracy_edges: 0.9975 - val_f1: 0.6444 - val_precision: 0.7088 - val_recall: 0.5907
# Epoch 98/100
# 20/20 [==============================] - 8s 364ms/step - loss: 125.4811 - accuracy_edges: 0.9971 - f1: 0.6286 - precision: 0.6759 - recall: 0.5878 - val_loss: 115.6632 - val_accuracy_edges: 0.9975 - val_f1: 0.6444 - val_precision: 0.7110 - val_recall: 0.5892
# Epoch 99/100
# 20/20 [==============================] - 8s 375ms/step - loss: 124.8889 - accuracy_edges: 0.9971 - f1: 0.6272 - precision: 0.6804 - recall: 0.5820 - val_loss: 115.9173 - val_accuracy_edges: 0.9975 - val_f1: 0.6410 - val_precision: 0.7131 - val_recall: 0.5821
# Epoch 100/100
# 20/20 [==============================] - ETA: 0s - loss: 127.2625 - accuracy_edges: 0.9971 - f1: 0.6216 - precision: 0.6821 - recall: 0.5713
# Epoch 100: saving model to /home/david/SemesterProject/Models/SceneNetFloorTiledTextureRandom/SGED_FOCAL_LOSS_0.5_g2_a2_REAL/CKPT/ckpt-loss=116.61-epoch=100.00-f1=0.6406
# WARNING:absl:Found untraced functions such as reset_state, reset_state while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /home/david/SemesterProject/Models/SceneNetFloorTiledTextureRandom/SGED_FOCAL_LOSS_0.5_g2_a2_REAL/CKPT/ckpt-loss=116.61-epoch=100.00-f1=0.6406/assets
# INFO:tensorflow:Assets written to: /home/david/SemesterProject/Models/SceneNetFloorTiledTextureRandom/SGED_FOCAL_LOSS_0.5_g2_a2_REAL/CKPT/ckpt-loss=116.61-epoch=100.00-f1=0.6406/assets
# 20/20 [==============================] - 20s 1s/step - loss: 127.2625 - accuracy_edges: 0.9971 - f1: 0.6215 - precision: 0.6820 - recall: 0.5711 - val_loss: 116.6079 - val_accuracy_edges: 0.9975 - val_f1: 0.6406 - val_precision: 0.7128 - val_recall: 0.5818

# %%
model_ckpt = os.listdir(paths['CKPT'])

f1_max = 0
for ckpt_name in model_ckpt:
    if float(ckpt_name[-4:]) > f1_max:
        f1_max = float(ckpt_name[-4:])
        model_path = paths['CKPT']+"/"+ckpt_name

custom_objects = {"BinaryAccuracyEdges": metrics.BinaryAccuracyEdges,
                  "F1Edges": metrics.F1Edges,
                  "<lambda>":loss}

model = tf.keras.models.load_model(model_path, custom_objects=custom_objects)

# %% [markdown]
# # training evolution

# %%
if TRAIN_MODEL:
    plot_losses = ["loss"]
    plot_metrics = ["accuracy_edges", "f1", "recall", "precision"]

    path = os.path.join(paths["FIGURES"],"training.svg")

    visualize.plot_training_results(res=history.history, losses=plot_losses, metrics=plot_metrics, save=SAVE, path=path)


    for img, label in train_ds.take(1):
        img, label = img, label

    predictions = model.predict(img)    
    predictions = tools.predict_class_postprocessing(predictions, threshold = 0.5)

    visualize.plot_images(images=img, labels=label, predictions=predictions, save=False, path=path, batch_size=BATCH_SIZE)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [17], in <module>
#       3 plot_metrics = ["accuracy_edges", "f1", "recall", "precision"]
#       5 path = os.path.join(paths["FIGURES"],"training.svg")
# ----> 7 visualize.plot_training_results(res=history.history, losses=plot_losses, metrics=plot_metrics, save=SAVE, path=path)
#      10 for img, label in train_ds.take(1):
#      11     img, label = img, label
#
# File ~/SemesterProject/SGED/Nets/visualize.py:40, in plot_training_results(res, losses, metrics, res_fine, epochs, save, path, max_f1)
#      38 # Plot Metrics
#      39 for i in range(len(metrics)):
# ---> 40     plt.subplot(dim[0], dim[1], i + 1 + len(losses))
#      42     if "accuracy" in metrics[i]:
#      43         plt.ylim([0.8, 1])
#
# File ~/SemesterProject/tf/lib/python3.8/site-packages/matplotlib/pyplot.py:1030, in subplot(*args, **kwargs)
#    1025     cbook._warn_external("The subplot index argument to subplot() appears "
#    1026                          "to be a boolean. Did you intend to use "
#    1027                          "subplots()?")
#    1029 fig = gcf()
# -> 1030 a = fig.add_subplot(*args, **kwargs)
#    1031 bbox = a.bbox
#    1032 byebye = []
#
# File ~/SemesterProject/tf/lib/python3.8/site-packages/matplotlib/figure.py:1419, in Figure.add_subplot(self, *args, **kwargs)
#    1411         else:
#    1412             # Undocumented convenience behavior:
#    1413             # subplot(111); subplot(111, projection='polar')
#    1414             # will replace the first with the second.
#    1415             # Without this, add_subplot would be simpler and
#    1416             # more similar to add_axes.
#    1417             self._axstack.remove(ax)
# -> 1419     a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1421 return self._add_axes_internal(key, a)
#
# File ~/SemesterProject/tf/lib/python3.8/site-packages/matplotlib/axes/_subplots.py:65, in SubplotBase.__init__(self, fig, *args, **kwargs)
#      63     else:
#      64         if num < 1 or num > rows*cols:
# ---> 65             raise ValueError(
#      66                 f"num must be 1 <= num <= {rows*cols}, not {num}")
#      67         self._subplotspec = GridSpec(
#      68                 rows, cols, figure=self.figure)[int(num) - 1]
#      69         # num - 1 for converting from MATLAB to python indexing
#      70 else:
#
# ValueError: num must be 1 <= num <= 4, not 5

# %% [markdown]
# # Metric Numerical Results After Fine Tuning on Real World Data

# %% [markdown]
# ## test

# %%
if not TRAIN_MODEL:
    step_width = 0.05
    threshold_range = [0.05,0.95]
    threshold_array = np.arange(threshold_range[0],threshold_range[1]+step_width,step_width)

    path_metrics_evaluation_plot = os.path.join(paths["FIGURES"],"POST_TRAINING", "metric_test_threshold{:.1f}.svg".format(0))
    threshold_MF_test = visualize.plot_threshold_metrics_evaluation_class(model=model, 
                                                                          ds=test_ds,
                                                                          num_classes = NUM_CLASSES,
                                                                          threshold_array=threshold_array,
                                                                          threshold_edge_width=0, 
                                                                          save=SAVE, 
                                                                          path=path_metrics_evaluation_plot,)

    path_metrics_evaluation_plot = os.path.join(paths["FIGURES"],"POST_TRAINING", "metric_test_threshold{:.1f}.svg".format(THRESHOLD_EDGE_WIDTH_REAL))
    visualize.plot_threshold_metrics_evaluation_class(model=model, 
                                                ds=test_ds,
                                                num_classes = NUM_CLASSES,
                                                threshold_array=threshold_array, 
                                                threshold_edge_width=THRESHOLD_EDGE_WIDTH_REAL, 
                                                save=SAVE, 
                                                path=path_metrics_evaluation_plot,)

# %% [markdown]
# ## test hard

# %% [markdown]
# if not TRAIN_MODEL:
#     step_width = 0.05
#     threshold_range = [0.05,0.95]
#     threshold_array = np.arange(threshold_range[0],threshold_range[1]+step_width,step_width)
#
#     path_metrics_evaluation_plot = os.path.join(paths["FIGURES"],"POST_TRAINING", "metric_test_hard_threshold{:.1f}.svg".format(0))
#     threshold_MF_test_hard = visualize.plot_threshold_metrics_evaluation_class(model=model,
#                                                                          ds=test_hard_ds,
#                                                                          num_classes = NUM_CLASSES,
#                                                                          threshold_array=threshold_array,
#                                                                          threshold_edge_width=0,
#                                                                          save=SAVE,
#                                                                          path=path_metrics_evaluation_plot)
#
#     path_metrics_evaluation_plot = os.path.join(paths["FIGURES"],"POST_TRAINING", "metric_test_hard_threshold{:.1f}.svg".format(THRESHOLD_EDGE_WIDTH_REAL))
#     visualize.plot_threshold_metrics_evaluation_class(model=model,
#                                                 num_classes = NUM_CLASSES
#                                                 ds=test_hard_ds,
#                                                 threshold_array=threshold_array,
#                                                 threshold_edge_width=THRESHOLD_EDGE_WIDTH_REAL,
#                                                 save=SAVE,
#                                                 path=path_metrics_evaluation_plot)

# %% [markdown]
# # Visual Results After Fine Tuning on Real World Data

# %% [markdown]
# ## test

# %%
if not TRAIN_MODEL:
    i = 1
    for img, label in test_ds.take(3):
        img, label = img, label

        threshold = 0.5
        predictions = model.predict(img)    
        predictions = tools.predict_class_postprocessing(predictions, threshold = threshold)

        path = os.path.join(paths["FIGURES"],"POST_TRAINING", "images_test_threshold_{:.2f}_{}".format(threshold, i))
        visualize.plot_images(images=img, labels=label, predictions=predictions, save=SAVE, path=path, batch_size=BATCH_SIZE)

        threshold = threshold_MF_test
        predictions = model.predict(img)    
        predictions = tools.predict_class_postprocessing(predictions, threshold = threshold)

        path = os.path.join(paths["FIGURES"],"POST_TRAINING", "images_test_threshold_ods_{}".format(i))
        visualize.plot_images(images=img, labels=label, predictions=predictions, save=SAVE, path=path, batch_size=BATCH_SIZE)

        i += 1

# %% [markdown]
# ## test hard

# %%
if not TRAIN_MODEL:
    i = 1
    for img, label in test_hard_ds.take(2):
        img, label = img, label

        threshold = 0.5

        predictions = model.predict(img)    
        predictions = tools.predict_class_postprocessing(predictions, threshold = threshold)

        path = os.path.join(paths["FIGURES"],"POST_TRAINING", "images_test_hard_threshold{:.2f}_{}".format(threshold,i))
        visualize.plot_images(images=img, labels=label, predictions=predictions, save=SAVE, path=path, batch_size=BATCH_SIZE)

        threshold = threshold_MF_test

        predictions = model.predict(img)    
        predictions = tools.predict_class_postprocessing(predictions, threshold = threshold)

        path = os.path.join(paths["FIGURES"],"POST_TRAINING", "images_test_hard_ods_{}".format(i))
        visualize.plot_images(images=img, labels=label, predictions=predictions, save=SAVE, path=path, batch_size=BATCH_SIZE)

        i += 1

# %% [markdown]
# ## test img

# %%
if not TRAIN_MODEL:
    for img in test_img_ds.take(1):
        img = img

    predictions = model.predict(img)
    
    #threshold = threshold_MF_test
    threshold = [0.6, 0.4, 0.3]
    predictions = tools.predict_class_postprocessing(predictions, threshold = threshold)

    path = os.path.join(paths["FIGURES"],"POST_TRAINING", "images_test_img")

    try:
        visualize.plot_images(images=img, labels=None, predictions=predictions, save=SAVE, path=path, batch_size=6)
    except:
        visualize.plot_images(images=img, labels=None, predictions=predictions, save=SAVE, path=path, batch_size=img_count_test_img)

# %% [markdown]
# # Save Model

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(),
                  loss=loss,
                  metrics={'output': [metrics.BinaryAccuracyEdges(threshold_prediction=0),
                                      metrics.F1Edges(threshold_prediction=0, threshold_edge_width=0)]})

if SAVE and TRAIN_MODEL:
    model.save(paths["MODEL"])
    
    custom_objects = {"BinaryAccuracyEdges": metrics.BinaryAccuracyEdges,
                      "F1Edges": metrics.F1Edges,
                      "<lambda>":loss}
    
    model = tf.keras.models.load_model(paths["MODEL"], custom_objects=custom_objects)
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: /home/david/SemesterProject/Models/SceneNetFloorTiledTextureRandom/SGED_FOCAL_LOSS_0.5_g2_a2_REAL/assets
# INFO:tensorflow:Assets written to: /home/david/SemesterProject/Models/SceneNetFloorTiledTextureRandom/SGED_FOCAL_LOSS_0.5_g2_a2_REAL/assets
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# # Addtional Elements to Consider in other Projects
#
# * Data augmentation for small datasets

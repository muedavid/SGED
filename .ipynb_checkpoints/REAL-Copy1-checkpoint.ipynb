# %% [markdown]
# # Remarks
#
# * Data normalization
#     * Mobilenet expects data from -1 to 1
#         * Normalize Input Data or Include in Model
#         * TFLite Conversion must fit according to decision
#     * Ground Truth Data: for better inspection Data multiplied by 80. Undo the change in the Data Input Pipeline
# * Overview in Tutorials:
#     * tf.function
#     * Repeat addapted Version of using Build in methods for training, ...
#     * Save models using keras
#         * CaseNet first real model: check in implementation of Frey if a Layer needs to be written
#         * other Example: depth seperable dilated convolution,
# * Idea
#     * Loss
#         * Focal Loss: for imbalanced Data
#         * In general Loss: just now weight in each dependent on number of Edge Pixels

# %% [markdown]
# # Libraries

# %%
#!for a in /sys/bus/pci/devices/*; do echo 0 | sudo tee -a $a/numa_node; done

import tensorflow as tf
import numpy as np
import os
import time
from datetime import datetime
#import sys
import matplotlib.pyplot as plt




import DataProcessing.data_processing as data_processing
import Nets.backbones as backbones
import Nets.features as features
import Nets.losses as losses
import Nets.metrics as metrics
import Nets.tools as tools


os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'

#np.set_printoptions(threshold=sys.maxsize)
# Out:
# 2022-05-04 11:12:18.318704: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-04 11:12:18.327089: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-04 11:12:18.327554: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-04 11:12:18.328461: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-05-04 11:12:18.328883: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-04 11:12:18.329333: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-04 11:12:18.329690: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-04 11:12:18.696618: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-04 11:12:18.697015: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-04 11:12:18.697359: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-04 11:12:18.697703: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2876 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 980, pci bus id: 0000:22:00.0, compute capability: 5.2

# %% [markdown]
# # Testing

# %% [markdown]
# # Options

# %%
#tf.config.run_functions_eagerly(True)

DATA = 'RealRed'
MODEL = 'CASENet_Real_New_Data'
OUTPUT_TRAIN = 'Train'
OUTPUT_TEST = 'Test'
HALF = True

IMG_SIZE_HEIGHT = 1280
IMG_SIZE_WIDTH = 720
NUM_CLASSES = 3
BATCH_SIZE = 3

MAX_IMG_TRAIN = 100
MAX_IMG_TEST = 20

CACHE = True
SEED = None

FINE_TUNING = True

EPOCHS = 10
fine_tune_epochs = 5

#Model Callback
MODEL_SAVE_EPOCH_FREQ = 5
DEL_CHECKPOINTS_OLD = False

# TENSORBOARD:
TENSORBOARD = False
DEL_OLD_TENSORBOARD = True

# SAVE
SAVE = False

# LOSS
WeightedMultiLabelSigmoidEdgeLoss = False
#betaUpper = tf.constant(0.995)
#betaLower = tf.constant(0.005)
betaUpper = tf.constant(0.95)
betaLower = tf.constant(0.05)
classWeighted = tf.constant(False)

FocalLoss = True
gamma=tf.constant(1) 
alpha=tf.constant(1) 
weighted_beta=tf.constant(True) 
Beta_upper=tf.constant(0.9) 
Beta_lower=tf.constant(0.1)
classWeighted=tf.constant(False)

#TESTING
test = False
if test:
    EPOCHS = 10
    MAX_IMG_TRAIN = 100
    MAX_IMG_TEST = 10

# %% [markdown]
# # Load Dataset, Preprocess Images and Dataset

# %%
#tf.random.set_seed(SEED)

paths, files = data_processing.path_definitions(HALF, MODEL, DATA, OUTPUT_TRAIN, OUTPUT_TEST)

data_processing.clean_model_directories(paths, DEL_CHECKPOINTS_OLD, DEL_OLD_TENSORBOARD)

train_ds, img_count_train = data_processing.loader(paths,"TRAIN", IMG_SIZE_HEIGHT, IMG_SIZE_WIDTH, HALF, MAX_IMG_TRAIN)
train_ds = data_processing.dataset_processing(train_ds, CACHE=CACHE, SHUFFLE = True, BATCH_SIZE = BATCH_SIZE, PREFETCH = True, img_count = img_count_train)

test_ds, img_count_test = data_processing.loader(paths,"TEST", IMG_SIZE_HEIGHT, IMG_SIZE_WIDTH, HALF, MAX_IMG_TEST)
test_ds = data_processing.dataset_processing(test_ds, CACHE=CACHE, SHUFFLE = True, BATCH_SIZE = BATCH_SIZE, PREFETCH = True, img_count = img_count_test)

#print("Memory Usage corresponds to: ",tf.config.experimental.get_memory_info('GPU:0')['current'])
# Out:
# /home/david/SemesterProject/Datasets/RealRed/Train/half/images
# The TRAIN Dataset contains 87 images.
# /home/david/SemesterProject/Datasets/RealRed/Test/half/images
# The TEST Dataset contains 10 images.

# %% [raw]
# for image,label in train_ds.take(1):
#     sample_image, sample_mask = image,label
#
# tools.plot_images(images=sample_image, labels=sample_mask, predictions=None, BS=3)

# %% [markdown]
# # Model

# %%
if WeightedMultiLabelSigmoidEdgeLoss:
    loss = lambda y_true, y_pred : losses.WeightedMultiLabelSigmoidLoss(y_true,y_pred,Beta_lower=Beta_lower,Beta_upper=Beta_upper, classWeighted=classWeighted)
elif FocalLoss:
    loss = lambda y_true, y_pred : losses.FocalLossEdges(y_true, y_pred, gamma=gamma, alpha=alpha, weighted_beta=weighted_beta,Beta_lower=Beta_lower,Beta_upper=Beta_upper, classWeighted=classWeighted)
else:
    raise ValueError("either FocalLoss or WeightedMultiLabelSigmoidLoss must be True")

custom_objects = {"BinaryAccuracy_Edges": metrics.BinaryAccuracy_Edges,
                      "Recall_Edges": metrics.Recall_Edges,
                      "Precision_Edges": metrics.Precision_Edges,
                      "<lambda>":loss}

model = tf.keras.models.load_model(paths["MODEL"], custom_objects=custom_objects)

#model.trainable = True
#print(len(model.layers))
#
#for layer in model.layers[0:150]:
#    layer.trainable = False
# Out:
# 188

# %%
for img, label in train_ds.take(1):
    img, label = img, label
    
predictions = model.predict(img)    
predictions = tools.predict_class_postprocessing(predictions[0], threshold = 0.5)

path = os.path.join(paths["FIGURES"],"fine_tuning_images_0,5")
tools.plot_images(images=img, labels=label, predictions=predictions,SAVE = SAVE, path = path, BS=3)
# Out:
# 2022-05-04 11:12:23.625905: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8100

# %% [markdown]
# # Compile and Train Model

# %%
if TENSORBOARD:
    # %load_ext tensorboard
    # %tensorboard --logdir /home/david/SemesterProject/Models/CASENet/logs

# %%
# same Loss function is applied to both outputs, thus I only pass one loss function

# learning rate schedule
# base_learning_rate = 0.00125
base_learning_rate = 0.005
end_learning_rate = 0.00125
decay_step = np.ceil(img_count_train / BATCH_SIZE)*EPOCHS
lr_schedule = tf.keras.optimizers.schedules.PolynomialDecay(base_learning_rate,decay_steps = decay_step,end_learning_rate = end_learning_rate, power = 0.9)

frequency = int(np.ceil(img_count_train / BATCH_SIZE)*MODEL_SAVE_EPOCH_FREQ)

logdir = os.path.join(paths['TBLOGS'], datetime.now().strftime("%Y%m%d-%H%M%S"))
callbacks = [tf.keras.callbacks.ModelCheckpoint(filepath = paths["CKPT"]+ "/ckpt-loss={loss:.2f}-epoch={epoch:.2f}",save_weights_only=False,save_best_only=False,monitor="val_loss",verbose=1,save_freq= frequency),
            tf.keras.callbacks.TensorBoard(log_dir=logdir,histogram_freq=1)]

# compile model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule),
              loss=loss,
              metrics={'output': [metrics.BinaryAccuracy_Edges(threshold = tf.constant(0),bs = BATCH_SIZE),
                                 metrics.Recall_Edges(),metrics.Precision_Edges()]})

history = model.fit(train_ds, epochs=EPOCHS, validation_data=test_ds, callbacks=callbacks)
# Out:
# Epoch 1/5
# 29/29 [==============================] - 18s 470ms/step - loss: 352.9027 - output_loss: 153.3518 - side5_loss: 199.5511 - output_accuracy_edges: 0.9908 - output_recall_edges: 0.6879 - output_precision_edges: 0.2850 - val_loss: 741.7307 - val_output_loss: 291.7218 - val_side5_loss: 450.0089 - val_output_accuracy_edges: 0.9890 - val_output_recall_edges: 0.5468 - val_output_precision_edges: 0.2750
# Epoch 2/5
# 29/29 [==============================] - 12s 427ms/step - loss: 269.2548 - output_loss: 110.2060 - side5_loss: 159.0488 - output_accuracy_edges: 0.9929 - output_recall_edges: 0.7190 - output_precision_edges: 0.3594 - val_loss: 673.5870 - val_output_loss: 265.2587 - val_side5_loss: 408.3283 - val_output_accuracy_edges: 0.9879 - val_output_recall_edges: 0.5951 - val_output_precision_edges: 0.2616
# Epoch 3/5
# 29/29 [==============================] - 12s 430ms/step - loss: 231.4401 - output_loss: 90.6401 - side5_loss: 140.8000 - output_accuracy_edges: 0.9935 - output_recall_edges: 0.7472 - output_precision_edges: 0.3884 - val_loss: 654.2018 - val_output_loss: 259.1447 - val_side5_loss: 395.0571 - val_output_accuracy_edges: 0.9877 - val_output_recall_edges: 0.6104 - val_output_precision_edges: 0.2620
# Epoch 4/5
# 29/29 [==============================] - 12s 427ms/step - loss: 214.3778 - output_loss: 81.2624 - side5_loss: 133.1154 - output_accuracy_edges: 0.9937 - output_recall_edges: 0.7841 - output_precision_edges: 0.4023 - val_loss: 644.0228 - val_output_loss: 257.7162 - val_side5_loss: 386.3065 - val_output_accuracy_edges: 0.9894 - val_output_recall_edges: 0.5636 - val_output_precision_edges: 0.2913
# Epoch 5/5
# 28/29 [===========================>..] - ETA: 0s - loss: 199.9340 - output_loss: 74.4853 - side5_loss: 125.4487 - output_accuracy_edges: 0.9940 - output_recall_edges: 0.8021 - output_precision_edges: 0.4184
# Epoch 5: saving model to /home/david/SemesterProject/Models/CASENet_Real_New_Data/CKPT/ckpt-loss=200.65-epoch=5.00
# 2022-05-04 11:13:33.433726: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: /home/david/SemesterProject/Models/CASENet_Real_New_Data/CKPT/ckpt-loss=200.65-epoch=5.00/assets
# 29/29 [==============================] - 20s 719ms/step - loss: 200.6543 - output_loss: 74.8240 - side5_loss: 125.8304 - output_accuracy_edges: 0.9939 - output_recall_edges: 0.8011 - output_precision_edges: 0.4186 - val_loss: 636.6040 - val_output_loss: 253.2901 - val_side5_loss: 383.3139 - val_output_accuracy_edges: 0.9885 - val_output_recall_edges: 0.6003 - val_output_precision_edges: 0.2764

# %% [markdown]
# # Plot Results

# %%
plot_losses = ["output_loss"]
plot_metrics = ["output_accuracy_edges", "output_recall_edges", "output_precision_edges"]

path = os.path.join(paths["FIGURES"],"training.svg")

tools.plot_training_results(res=history.history, losses=plot_losses, metrics=plot_metrics, SAVE=SAVE, path=path)

# %% [raw]
# ### F1:
#
# m = metrics.F1_Edges(threshold = tf.constant(0), widen = tf.constant(1), num_classes = tf.constant(NUM_CLASSES))
#
# for img, label in test_ds:
#     img, label = img, label
#
#
#     pred = model.predict(img)
#
#     m.update_state(label, pred[0])
#
# print(m.result()[0])

# %%
for img, label in test_ds.take(1):
    img, label = img, label
    
predictions = model.predict(img)

predictions = tools.predict_class_postprocessing(predictions[0], threshold = 0.5)

path = os.path.join(paths["FIGURES"],"images")
tools.plot_images(images=img, labels=label, predictions=predictions,SAVE = SAVE, path = path, BS=3)

# %% [markdown]
# # Fine Tuning

# %%
if FINE_TUNING:

    # Fine-tune from this layer onwards
    #fine_tune_output = output_names[4-1]

    model.trainable = True

    # Freeze all the layers before the `fine_tune_at` layer
    for layer in model.layers[0:100]:
        layer.trainable = False
        #if layer.name == fine_tune_output:
        #    break
    
    
    total_epochs =  EPOCHS + fine_tune_epochs

    base_learning_rate = 0.0001
    end_learning_rate = 0.0001
    decay_step = np.floor(img_count_train / BATCH_SIZE)*fine_tune_epochs
    lr_schedule = tf.keras.optimizers.schedules.PolynomialDecay(
        base_learning_rate,decay_steps = decay_step,end_learning_rate = end_learning_rate, power = 0.9)

    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule),
                  loss=loss,
                  metrics={'output': [metrics.BinaryAccuracy_Edges(threshold = tf.constant(0),bs = BATCH_SIZE), 
                                      metrics.Recall_Edges(),metrics.Precision_Edges()]})

    history_fine = model.fit(train_ds, epochs=total_epochs, 
                               initial_epoch=history.epoch[-1]+1,validation_data=test_ds, 
                               callbacks=callbacks)
    
    plot_losses = ["output_loss"]
    plot_metrics = ["output_accuracy_edges", "output_recall_edges", "output_precision_edges"]
    
    path = os.path.join(paths["FIGURES"],"fine_tuning_training.svg")
    
    tools.plot_training_results(res=history.history, res_fine = history_fine.history, 
                                losses=plot_losses, metrics=plot_metrics, SAVE=SAVE, path=path, EPOCHS = EPOCHS)
# Out:
# Epoch 6/20
# 29/29 [==============================] - 19s 538ms/step - loss: 197.5403 - output_loss: 73.2067 - side5_loss: 124.3335 - output_accuracy_edges: 0.9940 - output_recall_edges: 0.8057 - output_precision_edges: 0.4207 - val_loss: 642.8236 - val_output_loss: 258.2068 - val_side5_loss: 384.6168 - val_output_accuracy_edges: 0.9891 - val_output_recall_edges: 0.6318 - val_output_precision_edges: 0.3034
# Epoch 7/20
# 29/29 [==============================] - 15s 521ms/step - loss: 179.8501 - output_loss: 65.9498 - side5_loss: 113.9003 - output_accuracy_edges: 0.9940 - output_recall_edges: 0.8420 - output_precision_edges: 0.4287 - val_loss: 640.5704 - val_output_loss: 258.6217 - val_side5_loss: 381.9487 - val_output_accuracy_edges: 0.9890 - val_output_recall_edges: 0.6486 - val_output_precision_edges: 0.3046
# Epoch 8/20
# 29/29 [==============================] - 15s 518ms/step - loss: 173.6518 - output_loss: 63.9604 - side5_loss: 109.6914 - output_accuracy_edges: 0.9942 - output_recall_edges: 0.8438 - output_precision_edges: 0.4380 - val_loss: 657.2355 - val_output_loss: 266.1520 - val_side5_loss: 391.0834 - val_output_accuracy_edges: 0.9897 - val_output_recall_edges: 0.6163 - val_output_precision_edges: 0.3195
# Epoch 9/20
# 29/29 [==============================] - 15s 525ms/step - loss: 170.4220 - output_loss: 62.7466 - side5_loss: 107.6753 - output_accuracy_edges: 0.9943 - output_recall_edges: 0.8537 - output_precision_edges: 0.4399 - val_loss: 655.5049 - val_output_loss: 266.2255 - val_side5_loss: 389.2794 - val_output_accuracy_edges: 0.9894 - val_output_recall_edges: 0.6372 - val_output_precision_edges: 0.3155
# Epoch 10/20
# 28/29 [===========================>..] - ETA: 0s - loss: 167.9252 - output_loss: 61.9577 - side5_loss: 105.9674 - output_accuracy_edges: 0.9942 - output_recall_edges: 0.8589 - output_precision_edges: 0.4386
# Epoch 10: saving model to /home/david/SemesterProject/Models/CASENet_Real_New_Data/CKPT/ckpt-loss=168.36-epoch=10.00
# INFO:tensorflow:Assets written to: /home/david/SemesterProject/Models/CASENet_Real_New_Data/CKPT/ckpt-loss=168.36-epoch=10.00/assets
# 29/29 [==============================] - 24s 855ms/step - loss: 168.3554 - output_loss: 62.0805 - side5_loss: 106.2749 - output_accuracy_edges: 0.9942 - output_recall_edges: 0.8595 - output_precision_edges: 0.4376 - val_loss: 646.6460 - val_output_loss: 261.9724 - val_side5_loss: 384.6735 - val_output_accuracy_edges: 0.9900 - val_output_recall_edges: 0.6129 - val_output_precision_edges: 0.3274
# Epoch 11/20
# 29/29 [==============================] - 15s 517ms/step - loss: 167.9052 - output_loss: 62.1315 - side5_loss: 105.7737 - output_accuracy_edges: 0.9943 - output_recall_edges: 0.8530 - output_precision_edges: 0.4427 - val_loss: 633.2555 - val_output_loss: 256.0259 - val_side5_loss: 377.2296 - val_output_accuracy_edges: 0.9895 - val_output_recall_edges: 0.6364 - val_output_precision_edges: 0.3162
# Epoch 12/20
# 29/29 [==============================] - 16s 549ms/step - loss: 167.3095 - output_loss: 61.7815 - side5_loss: 105.5280 - output_accuracy_edges: 0.9943 - output_recall_edges: 0.8578 - output_precision_edges: 0.4407 - val_loss: 649.2668 - val_output_loss: 263.6684 - val_side5_loss: 385.5983 - val_output_accuracy_edges: 0.9894 - val_output_recall_edges: 0.6404 - val_output_precision_edges: 0.3160
# Epoch 13/20
# 29/29 [==============================] - 16s 552ms/step - loss: 163.9764 - output_loss: 60.7004 - side5_loss: 103.2760 - output_accuracy_edges: 0.9943 - output_recall_edges: 0.8621 - output_precision_edges: 0.4433 - val_loss: 685.3166 - val_output_loss: 278.6990 - val_side5_loss: 406.6175 - val_output_accuracy_edges: 0.9905 - val_output_recall_edges: 0.5834 - val_output_precision_edges: 0.3365
# Epoch 14/20
# 29/29 [==============================] - 15s 526ms/step - loss: 161.6547 - output_loss: 59.7190 - side5_loss: 101.9357 - output_accuracy_edges: 0.9944 - output_recall_edges: 0.8662 - output_precision_edges: 0.4470 - val_loss: 656.8873 - val_output_loss: 267.4101 - val_side5_loss: 389.4772 - val_output_accuracy_edges: 0.9900 - val_output_recall_edges: 0.6165 - val_output_precision_edges: 0.3279
# Epoch 15/20
# 28/29 [===========================>..] - ETA: 0s - loss: 158.4247 - output_loss: 58.8903 - side5_loss: 99.5345 - output_accuracy_edges: 0.9945 - output_recall_edges: 0.8600 - output_precision_edges: 0.4493
# Epoch 15: saving model to /home/david/SemesterProject/Models/CASENet_Real_New_Data/CKPT/ckpt-loss=160.72-epoch=15.00
# INFO:tensorflow:Assets written to: /home/david/SemesterProject/Models/CASENet_Real_New_Data/CKPT/ckpt-loss=160.72-epoch=15.00/assets
# 29/29 [==============================] - 25s 872ms/step - loss: 160.7232 - output_loss: 59.7274 - side5_loss: 100.9959 - output_accuracy_edges: 0.9944 - output_recall_edges: 0.8621 - output_precision_edges: 0.4474 - val_loss: 681.6911 - val_output_loss: 278.5422 - val_side5_loss: 403.1490 - val_output_accuracy_edges: 0.9898 - val_output_recall_edges: 0.6065 - val_output_precision_edges: 0.3217
# Epoch 16/20
# 29/29 [==============================] - 15s 516ms/step - loss: 161.1823 - output_loss: 59.6172 - side5_loss: 101.5651 - output_accuracy_edges: 0.9945 - output_recall_edges: 0.8613 - output_precision_edges: 0.4505 - val_loss: 679.2450 - val_output_loss: 276.1760 - val_side5_loss: 403.0689 - val_output_accuracy_edges: 0.9901 - val_output_recall_edges: 0.6042 - val_output_precision_edges: 0.3282
# Epoch 17/20
# 29/29 [==============================] - 15s 523ms/step - loss: 161.3796 - output_loss: 59.9342 - side5_loss: 101.4454 - output_accuracy_edges: 0.9943 - output_recall_edges: 0.8647 - output_precision_edges: 0.4448 - val_loss: 684.0731 - val_output_loss: 279.3766 - val_side5_loss: 404.6964 - val_output_accuracy_edges: 0.9899 - val_output_recall_edges: 0.6103 - val_output_precision_edges: 0.3230
# Epoch 18/20
# 29/29 [==============================] - 15s 526ms/step - loss: 160.7315 - output_loss: 59.3941 - side5_loss: 101.3375 - output_accuracy_edges: 0.9944 - output_recall_edges: 0.8692 - output_precision_edges: 0.4484 - val_loss: 685.8250 - val_output_loss: 281.2397 - val_side5_loss: 404.5853 - val_output_accuracy_edges: 0.9897 - val_output_recall_edges: 0.6139 - val_output_precision_edges: 0.3210
# Epoch 19/20
# 29/29 [==============================] - 15s 527ms/step - loss: 158.5269 - output_loss: 58.9799 - side5_loss: 99.5470 - output_accuracy_edges: 0.9945 - output_recall_edges: 0.8677 - output_precision_edges: 0.4511 - val_loss: 718.9533 - val_output_loss: 294.5367 - val_side5_loss: 424.4167 - val_output_accuracy_edges: 0.9904 - val_output_recall_edges: 0.5814 - val_output_precision_edges: 0.3335
# Epoch 20/20
# 28/29 [===========================>..] - ETA: 0s - loss: 154.7740 - output_loss: 57.3797 - side5_loss: 97.3943 - output_accuracy_edges: 0.9946 - output_recall_edges: 0.8702 - output_precision_edges: 0.4519
# Epoch 20: saving model to /home/david/SemesterProject/Models/CASENet_Real_New_Data/CKPT/ckpt-loss=158.05-epoch=20.00
# INFO:tensorflow:Assets written to: /home/david/SemesterProject/Models/CASENet_Real_New_Data/CKPT/ckpt-loss=158.05-epoch=20.00/assets
# 29/29 [==============================] - 24s 828ms/step - loss: 158.0519 - output_loss: 58.6902 - side5_loss: 99.3617 - output_accuracy_edges: 0.9945 - output_recall_edges: 0.8693 - output_precision_edges: 0.4507 - val_loss: 717.5873 - val_output_loss: 294.4772 - val_side5_loss: 423.1100 - val_output_accuracy_edges: 0.9903 - val_output_recall_edges: 0.5794 - val_output_precision_edges: 0.3322

# %% [raw]
# acc += history_fine["..."]
# plt.figure(figsize=(8, 8))
# plt.subplot(2, 1, 1)
# plt.plot(acc, label='Training Accuracy')
# plt.plot(val_acc, label='Validation Accuracy')
# #plt.ylim([0.8, 1])
# plt.plot([EPOCHS-1,EPOCHS-1],
#           plt.ylim(), label='Start Fine Tuning')
# plt.legend(loc='lower right')
# plt.title('Training and Validation Accuracy')
#
# plt.subplot(2, 1, 2)
# plt.plot(loss, label='Training Loss')
# plt.plot(val_loss, label='Validation Loss')
# #plt.ylim([0, 1.0])
# plt.plot([EPOCHS-1,EPOCHS-1],
#          plt.ylim(), label='Start Fine Tuning')
# plt.legend(loc='upper right')
# plt.title('Training and Validation Loss')
# plt.xlabel('epoch')
# plt.show()

# %% [markdown]
# # Predictions

# %%
for img, label in test_ds.take(2):
    img, label = img, label
    
predictions = model.predict(img)    
predictions = tools.predict_class_postprocessing(predictions[0], threshold = 0.5)

path = os.path.join(paths["FIGURES"],"fine_tuning_images_0,5")
tools.plot_images(images=img, labels=label, predictions=predictions,SAVE = SAVE, path = path, BS=3)

# %% [markdown]
# # Save Model

# %%
if SAVE:
    model.save(paths["MODEL"])
    
    custom_objects = {"BinaryAccuracy_Edges": metrics.BinaryAccuracy_Edges,
                      "Recall_Edges": metrics.Recall_Edges,
                      "Precision_Edges": metrics.Precision_Edges,
                      "lambda":loss}

# %% [markdown]
# # Predict Real Images

# %%
def predict_real(path,HEIGHT,WIDTH):
    image = tf.io.read_file(path)
    image = tf.image.decode_png(image, channels=3)
    image = tf.cast(image, tf.float32)
    image = tf.expand_dims(image,axis = 0)
    image = tf.image.resize(image,(IMG_SIZE_HEIGHT, IMG_SIZE_WIDTH))
    pred = model.predict(image)
    
    val_max = tf.reduce_max(pred[0], axis = -1)
    idx_max = tf.argmax(pred[0], axis = -1) + 1

    predictions = tf.where(val_max >= 0, idx_max, 0)

    predictions = tf.expand_dims(predictions, axis = -1)

    return image,predictions

# %%
IMG_SIZE_HEIGHT = 1280
IMG_SIZE_WIDTH = 720

imgs = [1,3,4,5, 6]
path = '/home/david/test_images/'
Data = {'img':[],'mask':[]}

for i in imgs:
    img, mask = predict_real(path+str(i)+'.png',IMG_SIZE_HEIGHT,IMG_SIZE_WIDTH)
    Data['img'].append(img)
    Data['mask'].append(mask)


plt.figure(figsize=(10, 50))
size = len(Data['img'])
for k in range(size):
    plt.subplot(size,2, k*2+1)
    plt.title("Images")
    plt.imshow(tf.keras.preprocessing.image.array_to_img(Data['img'][k][0,:,:,:]))
    plt.subplot(size,2, k*2+2)
    plt.title("Estimation")
    plt.imshow(Data['mask'][k][0,:,:,0],cmap='gray')
    plt.axis('off')

if SAVE:
    plt.savefig(os.path.join(paths["FIGURES"],'real.svg'), bbox_inches='tight')
plt.show()

# %% [markdown]
# # Addtional Elements to Consider in other Projects
#
# * Data augmentation for small datasets
